# %%
import googleapiclient.discovery
from googleapiclient.discovery import build
import pymongo 
import psycopg2
import pandas as pd
import json
import streamlit as st

# %%
api_service_name = "youtube"
api_version = "v3"
client_secrets_file = "YOUR_CLIENT_SECRET_FILE.json"

Api_Key = "AIzaSyA44pT-IRb6JjdazazOd6zdoZ95JrrzLlQ"
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey= Api_Key)

# %%
# Get channel infos
def get_ch_info(Channel_ID):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id= Channel_ID
    )
    response = request.execute()


    for results in response["items"]:
        d1 = dict(Channel_name = results['snippet']['title'],
                channel_id = results['id'],
                Subscription_Count = results['statistics']['subscriberCount'],
                Channel_Views = results['statistics']['viewCount'],
                Channel_Description = results['snippet']['description']
                )
    return d1

# %%
c = get_ch_info('UCiEmtpFVJjpvdhsQ2QAhxVA')

# %%
c
# Out:
# {'Channel_name': "GUVI's Zen Class",
#  'channel_id': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#  'Subscription_Count': '10000',
#  'Channel_Views': '886529',
#  'Channel_Description': 'Welcome to ZenClass Channel! \n\nZen Class is one of the industry’s leading Project-Based Career Program from GUVI - IIT-M Incubated Company. We provide online live classes programs with 100% Job Placement Support.\n\nFull Stack Developer Program - https://bit.ly/3Cc4REq\n\nIIT Certified Programming Professional & Master Data Science - https://bit.ly/3DoUjTC\n\nAutomation Testing Program - https://bit.ly/3wJpAhV\n\nMaster Cyber Security & Ethical Hacking Program - https://bit.ly/30m5spF\n\nCall +91-9344419057 for more details\n'}

# %%
def get_video_ids(Channel_ID):
    video_IDS = []

    request = youtube.channels().list(
        part="contentDetails",
        id=Channel_ID
    )
    response = request.execute()

    uploads_playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None

    while True:
        playlist_items_request = youtube.playlistItems().list(
            part="snippet",
            playlistId=uploads_playlist_id,
            maxResults=50,
            pageToken=next_page_token
        )
        playlist_items_response = playlist_items_request.execute()

        for item in playlist_items_response['items']:
            video_IDS.append(item['snippet']['resourceId']['videoId'])

        next_page_token = playlist_items_response.get('nextPageToken')

        if not next_page_token:
            break

    return video_IDS

# Usage
# channel_id = "UCniKMtxy7wpM7rO58qP177w"
# video_ids = get_video_ids(channel_id)
# print(video_ids)

# %%
All_Video_IDs= get_video_ids("UCiEmtpFVJjpvdhsQ2QAhxVA")

# %%
All_Video_IDs

# %%
# Get video_ID's infos using playlistID

def get_videoid_info(Channel_ID):
    video_IDS = []

    request = youtube.channels().list(
        part="contentDetails",
        id=Channel_ID
    )
    response = request.execute()

    Playlist_info = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    Initial_page_token = None  # Initialize full_page_token outside the loop

    while True:
        response = youtube.playlistItems().list(
            part="snippet",
            playlistId=Playlist_info,
            maxResults=50,
            pageToken= Initial_page_token
        ).execute()

        for vi in range(len(response['items'])):
            video_IDS.append(response['items'][vi]['snippet']['resourceId']['videoId'])

        Initial_page_token = response.get('nextPageToken')  # Update full_page_token

        if Initial_page_token is None:
            break
    return video_IDS

# %%
All_Video_IDs = get_videoid_info('UCiEmtpFVJjpvdhsQ2QAhxVA')

# %%
All_Video_IDs

# %%
#Get video info

def get_video_info(Channel_ID):
    All_video_info = []

    for video_info in All_Video_IDs:
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=video_info
        )
        response = request.execute()

        for item in response["items"]:
            d2 = dict(
                Video_Id=item['id'],
                Channel_Name=item['snippet']['channelTitle'],
                Channel_ID=item['snippet']['channelId'],
                Video_Name=item['snippet']['title'],
                Video_Description=item['snippet'].get('description'),
                Tags=item['snippet'].get('tags'),
                PublishedAt=item['snippet']['publishedAt'],
                View_Count=item['statistics'].get('viewCount'),
                Like_Count=item['statistics'].get('likeCount'),
                Dislike_Count=item['statistics'].get('dislikeCount'),
                Favorite_Count=item['statistics']['favoriteCount'],
                Comment_Count=item['statistics'].get('commentCount'),
                Duration=item['contentDetails']['duration'],
                Thumbnail=item['snippet']['thumbnails']['default']['url'],
                caption_status=item['contentDetails']['caption']
            )
            All_video_info.append(d2)

    return All_video_info

# %%
v = get_video_info("UCiEmtpFVJjpvdhsQ2QAhxVA")

# %%
v
# Out:
# [{'Video_Id': 'Rwh7Na4ynyc',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "From Non-IT to IT, Listen to Shivam's Transformation with GUVI's Guidance | Testimonial",
#   'Video_Description': 'To know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔ Placement Guidance Provided \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-04-30T12:30:31Z',
#   'View_Count': '33',
#   'Like_Count': '0',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M58S',
#   'Thumbnail': 'https://i.ytimg.com/vi/Rwh7Na4ynyc/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '8Q7_sSTcy4c',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Iyappan| "Unleashing the Power of Data: A Journey Through Data Science- Testimonial Spotlight"',
#   'Video_Description': '🌟 Dive into the incredible journey of Iyappan as they share their firsthand experience with our cutting-edge Data Science Course! 🚀\n\nTo know more about our Data Science Program - https://bit.ly/4bThY0q\n\nBenefits of the Program :\n\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial  #datascientist #DataScience #GUVIMentors #SuccessStories',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-03-11T12:45:00Z',
#   'View_Count': '183',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M56S',
#   'Thumbnail': 'https://i.ytimg.com/vi/8Q7_sSTcy4c/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'rYt4RFSxYuc',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Dinesh Kumar Empowering Success: Unveiling the Supportive Side of GUVI Mentors| Data Science online',
#   'Video_Description': "Unlock the key to success with Dinesh Kumar as he shares his transformative journey in the world of Data Science with GUVI mentors. In this compelling video, witness the unwavering support and guidance provided by GUVI mentors that played a pivotal role in empowering Dinesh's success. \n\nTo know more about our Data Science Program - https://bit.ly/4bThY0q\n\nBenefits of the Program :\n\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial  #datascientist #DataScience #GUVIMentors #SuccessStories",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-02-28T12:45:05Z',
#   'View_Count': '147',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M9S',
#   'Thumbnail': 'https://i.ytimg.com/vi/rYt4RFSxYuc/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'fEMROKW3pDE',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Hari prasath| "Banker to Data Scientist: Unveiling My Career Shift!" | Data science course| GUVI',
#   'Video_Description': 'Embark on a transformative journey with Hari Prasath as he shares the story of transitioning from the world of US Market Banking to becoming a Certified Data Scientist. \n\nTo know more about our Data Science Program - https://bit.ly/4bThY0q\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-02-25T12:45:02Z',
#   'View_Count': '146',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT1M35S',
#   'Thumbnail': 'https://i.ytimg.com/vi/fEMROKW3pDE/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'l1RWu7qU1sc',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Nivetha Shanmugam | Process Associate to Certified Data Scientist| Data Science success journey|',
#   'Video_Description': 'Listen to Nivetha and how she changed her career drastically with the help of GUVI. \n\nTo know more about our Data Science Program - https://bit.ly/4bThY0q\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-02-23T13:45:41Z',
#   'View_Count': '204',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M49S',
#   'Thumbnail': 'https://i.ytimg.com/vi/l1RWu7qU1sc/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '5DoR_veNWOA',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': '"Exploring the Data Science Journey: Sadhil Chhabra\'s Insightful GUVI Program Experience"',
#   'Video_Description': 'Sadhil Chhabra shares his learning experience about data science program at GUVI.\n\nTo know more about our Data Science Program - https://bit.ly/4bThY0q\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-02-19T13:00:10Z',
#   'View_Count': '76',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT1M20S',
#   'Thumbnail': 'https://i.ytimg.com/vi/5DoR_veNWOA/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'j2mttQysedU',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "PRITVI's Success Story as a Certified Data Scientist with GUVI | Testimonial | Zen Class | GUVI",
#   'Video_Description': 'Listen to Pritvi who is from a Zero coding background and completed his course successfully at GUVI\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Easy EMI Options\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-01-28T11:30:29Z',
#   'View_Count': '195',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT45S',
#   'Thumbnail': 'https://i.ytimg.com/vi/j2mttQysedU/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'rT6jXTptXFc',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "Checkout Nikash's Upskilling Journey with GUVI's Data Science Program | Testimonial | GUVI",
#   'Video_Description': "Dive into Nikash's insights on the Data Science Program by GUVI.\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-01-26T12:30:35Z',
#   'View_Count': '127',
#   'Like_Count': '0',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/rT6jXTptXFc/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'pq0vFGq5uxU',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "Gopinath's Transformation with GUVI's Data Science Program | Testimonial | Data Science Program",
#   'Video_Description': "Gopinath started by learning the basics of statistics and programming languages like Python and R—essential tools for a Data Scientist. GUVI's hands-on approach allowed him to practice these skills with real-world data, making it easier for him to grasp the concepts.\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-01-23T12:00:48Z',
#   'View_Count': '118',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M9S',
#   'Thumbnail': 'https://i.ytimg.com/vi/pq0vFGq5uxU/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'nKAvvlrxQJs',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Subash| How I entered IT industry from Mechanical background| Python Automation Testing Course',
#   'Video_Description': 'Subash who came from mechanical background, after joining GUVI he was able to crack the interview and became a software Automation Tester. \n\nTo know more about our Automation Testing Program - https://bit.ly/47xBrRq\n\nBenefits of the Program :\n✔ Assured Placement support\n✔ GUVI Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['#automation testing',
#    '#selinium testing',
#    '#automation testing online',
#    '#freeautomation testing course',
#    'Free online course',
#    'automation testing with selenium'],
#   'PublishedAt': '2024-01-16T13:00:43Z',
#   'View_Count': '98',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M43S',
#   'Thumbnail': 'https://i.ytimg.com/vi/nKAvvlrxQJs/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'a4Y_GtnhJHY',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Sandeep| Mechanical Engineer to Certified Data Scientist| Success Story| Testimonial| Data Science',
#   'Video_Description': "GUVI's Success Story - Check out Sandeep's Review of our Data Science Program.\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2024-01-14T13:00:00Z',
#   'View_Count': '238',
#   'Like_Count': '7',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT3M48S',
#   'Thumbnail': 'https://i.ytimg.com/vi/a4Y_GtnhJHY/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '_GeNIXgx_wo',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Padmini Kadhirvel| How I stared my Career after long years? Transformation of my life! | Zen Class',
#   'Video_Description': 'Listen to Padmini how she started her career in automation testing after her mariage. \n\nTo know more about our Automation Testing Program - https://bit.ly/3TYko7l\n\nBenefits of the Program :\n✔ Assured Placement support\n✔ GUVI Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['#automation testing',
#    '#selinium testing',
#    '#automation testing online',
#    '#freeautomation testing course',
#    'Free online course',
#    'automation testing with selenium'],
#   'PublishedAt': '2024-01-12T13:00:34Z',
#   'View_Count': '110',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M21S',
#   'Thumbnail': 'https://i.ytimg.com/vi/_GeNIXgx_wo/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'jZnhmNBTqvI',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'How I became a Mechanical engineer to Automation tester? Java Automation testing course| Selenium',
#   'Video_Description': 'In this video, Puvi Arasan has explained the flow of Zen Class clearly.\n\nTo know more about our Automation Testing Program - https://bit.ly/48Cu4si\n\nBenefits of the Program :\n✔ Assured Placement support\n✔ GUVI Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['#automation testing',
#    '#selinium testing',
#    '#automation testing online',
#    '#freeautomation testing course',
#    'Free online course',
#    'automation testing with selenium',
#    '#freeselinium course'],
#   'PublishedAt': '2024-01-09T13:15:07Z',
#   'View_Count': '92',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M41S',
#   'Thumbnail': 'https://i.ytimg.com/vi/jZnhmNBTqvI/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'SyNGmZbfVic',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Subramani| Mechanical Engineering to Web Developer! How? Success Journey| Full Stack course| GUVI',
#   'Video_Description': 'Our student Subramani who came from Mechanical background with Zero coding knowledge and now he was able to develop a web application by his own with the help of GUVI. \n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming',
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2024-01-07T13:15:01Z',
#   'View_Count': '140',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/SyNGmZbfVic/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'rXcGhHiWQlE',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Sowmya| How I transformed my career into Web Development?| Full Stack Development online course',
#   'Video_Description': 'Listen to Sowmya that how she transformed her career from Quality Engineer to Web Development. \n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming',
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2024-01-05T13:15:05Z',
#   'View_Count': '120',
#   'Like_Count': '0',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/rXcGhHiWQlE/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'pzo46i2gEaw',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Sachin| GUVI provides various platform for Practices| Testimonial| Full Stack Course Online',
#   'Video_Description': 'Listen to Sachin who shares his experience about GUVI.\n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming',
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2024-01-02T14:00:36Z',
#   'View_Count': '57',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT53S',
#   'Thumbnail': 'https://i.ytimg.com/vi/pzo46i2gEaw/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'HghdMRFmLQ0',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "Checkout Mohammed's journey as he embarks on a career in IT | Full Stack Developer Program | GUVI",
#   'Video_Description': 'Embarking on an inspiring journey, Mohammed sets out to establish his career in the dynamic field of IT. Fueled by passion and determination, he navigates challenges with resilience, turning obstacles into stepping stones. \n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming',
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2023-12-31T13:30:10Z',
#   'View_Count': '72',
#   'Like_Count': '0',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M20S',
#   'Thumbnail': 'https://i.ytimg.com/vi/HghdMRFmLQ0/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '3N2Jqhe4cx8',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Keerthana Kickstarted Her Tech Career With GUVI | Full Stack Development Program | Testimonial| GUVI',
#   'Video_Description': 'Discover how Keerthana developed her technical skills from GUVI.\n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming',
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2023-12-29T12:30:01Z',
#   'View_Count': '89',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT57S',
#   'Thumbnail': 'https://i.ytimg.com/vi/3N2Jqhe4cx8/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '6ApXNp2xjfU',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "From Sales Executive to Web Developer - Gopinath's Journey | Full Stack Development Program | GUVI",
#   'Video_Description': "Meet Gopinath, a dedicated professional from Non-Tech Background, on his remarkable journey with GUVI's Full Stack Development Program.\n\nTo enroll in the Full Stack Developer Program, click here -https://bit.ly/4651gYr\n\nGrab this limited-time opportunity & get trained by Industry- Proficient in this Full Stack Developer Program.\n\nBenefits of the Program\n✔  Assured Placement Opportunities\n✔  Globally Recognition Certification \n✔  Learn from Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n✔  Classes available in Tamil, English, Kannada & Hindi.\n\n#placement\u200b #job\u200b  #onlinecourse #zenclass #zenclassofficial #fullstack #guviofficial #fullstackdevelopercoursewithplacement #fullstackdevelopercoursefee #youtubeshorts #fullstackwebdevelopment #guvi #coding #programming",
#   'Tags': ['Full Stack',
#    'How to become a Full Stack Developer',
#    'How to become a MERN Stack Developer',
#    'Learn Full Stack Developer',
#    'Learn Full Stack',
#    'Learn Full Stack Development',
#    'Full Stack Developer',
#    'Full Stack Development',
#    'Full Stack Tutorial',
#    'Full Stack Learn',
#    'Free Full Stack Coaching',
#    'MERN Stack Developer',
#    'MERN Stack Development',
#    'Frontend development',
#    'Software Developer',
#    'Software development',
#    'Placement',
#    'testimonial',
#    'Zen Class',
#    '#fsdonlinecourse',
#    '#fullstackdevelopmentjobs'],
#   'PublishedAt': '2023-12-27T13:30:02Z',
#   'View_Count': '121',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M2S',
#   'Thumbnail': 'https://i.ytimg.com/vi/6ApXNp2xjfU/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'LWcdQnYkBYk',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Transitioning from mechanical engineering to embarking on a coding career | Testimonial | GUVI',
#   'Video_Description': "Thanks to GUVI's easy teaching, I went from mechanical engineering to starting a career in coding.\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2023-12-22T13:30:10Z',
#   'View_Count': '105',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M29S',
#   'Thumbnail': 'https://i.ytimg.com/vi/LWcdQnYkBYk/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'H07EMEHuWpA',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "From Program Completion to Job Offers: Naresh's Journey with GUVI | Testimonial | Data Science",
#   'Video_Description': "GUVI's Success Story - Check out Naresh's Review of our Data Science Program.\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2023-12-20T12:30:10Z',
#   'View_Count': '177',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/H07EMEHuWpA/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'tTElUHfNxkw',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': "Transformative Journey of Vasanth with GUVI's Data Science Program | Testimonial | GUVI",
#   'Video_Description': "Check Out Vasanth's Story in Our Data Science Program!\n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist",
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2023-12-18T13:00:52Z',
#   'View_Count': '131',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/tTElUHfNxkw/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'r_6oj5WJE-4',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Logesh Kumar| Business analytics course| Digital marketing course online| Zen Class| GUVI',
#   'Video_Description': 'Listen to Logesh Kumar who shares what are all he learnt while learning Business analytics with Digital marketing course at GUVI.\n\nTo know more about our Master’s in Business Analytics and Digital Marketing - https://bit.ly/3Ra9Wqs\n\nBenefits of the Program:\n\nA program designed by Subject-Matter Experts\nWeekend LIVE classes + Lifetime recorded videos\nOne-on-One with Mentors\nAsk me anything sessions with Industry Experts\nGlobally Recognized Certification from GUVI\nA digital portfolio through "Github"\nUpto 24 months of EMI options available\n7-day Refund Policy\n100% Job Placement Assistance - 50+ Interview\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #digitalmarketing #businessanalystcourse #digitalmarketingcourse',
#   'Tags': ['#businessalaytics',
#    '#digitalmarketingcourse',
#    'Digitalmarketingonlinecourse',
#    '#businessalanyticscourse'],
#   'PublishedAt': '2023-12-07T14:00:46Z',
#   'View_Count': '255',
#   'Like_Count': '3',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M41S',
#   'Thumbnail': 'https://i.ytimg.com/vi/r_6oj5WJE-4/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'qXmyFh8wAVE',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Manish Yadav| "Are GUVI\'s fees cost-effective?" | Data Science testimonials| Zen Class from GUVI',
#   'Video_Description': 'Manish Yadav shares his experience at GUVI while learning Data Science course.  \n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2023-12-01T14:00:40Z',
#   'View_Count': '189',
#   'Like_Count': '1',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M13S',
#   'Thumbnail': 'https://i.ytimg.com/vi/qXmyFh8wAVE/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'cnt2ZKJUEIc',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Arush James| From Non IT background to Machine Learning Expert! How?| Machine Learning Course| GUVI',
#   'Video_Description': 'Listen to Arush James who shares his experience while learning Machiine Learning course at GUVI.\n\nTo know more about our Machine Learning Program - https://bit.ly/3sX7ueF\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Globally Recognized Skill Certifications\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['#MachineLearning',
#    '#OnlineCourse',
#    '#DataScience',
#    '#ArtificialIntelligence',
#    '#TechEducation',
#    '#CodingSkills',
#    '#PythonProgramming',
#    '#LearnML',
#    '#DeepLearning',
#    '#NeuralNetworks',
#    '#MLAlgorithm',
#    'machinelearningonline',
#    'machinelearningcourse',
#    'machinelearningprogram'],
#   'PublishedAt': '2023-11-29T13:15:04Z',
#   'View_Count': '142',
#   'Like_Count': '2',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M55S',
#   'Thumbnail': 'https://i.ytimg.com/vi/cnt2ZKJUEIc/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '6oSbkD9EAG0',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'CHETHAN B RAJ| Data Science Online Course| Testimonial| Success Story of GUVI| Zen Class',
#   'Video_Description': 'Chethan Raj shares his experience at GUVI while learning Data Science course.  \n\nTo know more about our Data Science Program - https://bit.ly/3PIpOzs\n\nBenefits of the Program :\n✔  Assured Placement Opportunities\n✔  IIT-M Pravartak Certification\n✔  Learn from IIT & Industry Professionals\n✔  Live Online Classes\n✔  Work on 20+ projects\n\nGet in touch with us for regular updates. Follow our Social Media platforms and other platforms\n\nInstagram- https://www.instagram.com/guviofficial/?hl=en\nLinkedin-https://www.linkedin.com/company/guviofficial/viewAsMember=true\n\n#shorts #shortsvideo #shortsfeed #shortsyoutube #placement\u200b #job\u200b  #onlinecourse #zenclass #guvi #guviofficial #zenclassofficial #datascience #datascientist',
#   'Tags': ['python',
#    'data science career change',
#    'data science interview questions',
#    'data science journey',
#    'data scientist salary',
#    'data science career',
#    'data science training',
#    'how to learn data science',
#    'data scientist',
#    'data science',
#    'data science with python',
#    'datascience',
#    'learn data science',
#    'data science for beginners',
#    'data science tutorial for beginners',
#    'data science explained',
#    'data science course',
#    'introduction to data science',
#    'data science placement',
#    'data science full course',
#    'coding',
#    'programming'],
#   'PublishedAt': '2023-11-28T13:15:00Z',
#   'View_Count': '94',
#   'Like_Count': '0',
#   'Dislike_Count': None,
# ...
#   'Comment_Count': '0',
#   'Duration': 'PT1M10S',
#   'Thumbnail': 'https://i.ytimg.com/vi/gVShqL2tOTM/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'm2YAVSYGa-Q',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'FCA Student to Back End Developer | Zen Class Placement | GUVI',
#   'Video_Description': 'Is it possible for Non-CS Background to become a Developer?\n\nWe, at ZEN, will make it happen! Here is an example - Vinay Chatruvedi (FCA Student) from the Zen class was placed in a reputed company with a good package. \n\nWe always believe having relevant skills will ease up the process of getting hired irrespective of which degree you have.\n\nVinay Chatruvedi did the right thing by choosing Zen Class to get skilled in Full Stack Development. He did it with interest & passion and finally, he got placed in a company with a good package.\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career with ZEN’s Globally recognized Certification.\n\nTo enroll in Zen class, click here - https://bit.ly/2UXmp7S\n\nBenefits of Zen class\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry- recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/2UXmp7S\n\n#fullstack #fullstackdeveloper #frontend #fullstackdevelopment #zenclass #guvi #java #python #mysql #html #javascript #whatisfullstack #fullstackwebdevelopment #fullstackdevelopment #career #job #successstory',
#   'Tags': ['full stack',
#    'backend',
#    'frontend',
#    'developer',
#    'Full stack developer',
#    'front end developer',
#    'placement',
#    'full stack developer course with placement'],
#   'PublishedAt': '2021-07-31T05:47:06Z',
#   'View_Count': '3897',
#   'Like_Count': '29',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '8',
#   'Duration': 'PT2M24S',
#   'Thumbnail': 'https://i.ytimg.com/vi/m2YAVSYGa-Q/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'eAR1JHjKf2A',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'What is the Eligibility to Become a Full Stack Developer? | Zen Q&A Series',
#   'Video_Description': 'Become a Full Stack Developer in 90 days - https://bit.ly/3xaKVPy\n\nMoving to the next question on the Zen Class Q&A series on Full Stack Development. In this video, Mr Arun Prakash, Founder & COO - GUVI, will explain to you in detail the Eligibility to learn Full Stack Development.\n\nSubscribe to our channel & enjoy learning at ease.\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career as Full Stack Developer with Globally recognized Certification.\n\nBenefits of Zen class - Full Stack Development Program\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry-recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3xaKVPy\n\n#fullstack #fullstackdeveloper #frontend #fullstackdevelopment #zenclass #guvi #java #python #mysql #html #javascript #whatisfullstack #fullstackwebdevelopment #fullstackdevelopment #career #job',
#   'Tags': ['Full Stack',
#    'Fullstack',
#    'Fullstackdevelopment',
#    'Full Stack Developer'],
#   'PublishedAt': '2021-07-28T11:27:59Z',
#   'View_Count': '2288',
#   'Like_Count': '38',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '5',
#   'Duration': 'PT1M19S',
#   'Thumbnail': 'https://i.ytimg.com/vi/eAR1JHjKf2A/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'XjxdD2xn4GQ',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'What is the Duration to learn Full Stack Development? | Zen Class Q&A Series',
#   'Video_Description': 'Become a Full Stack Developer in 90 days - https://bit.ly/3rBNtVK\n\nMoving to the next question on the Zen Class Q&A series on Full Stack Development. In this video, Mr Arun Prakash, Founder & COO - GUVI, will explain to you in detail the time duration to learn Full Stack Development. If you are someone planning to start learning Full Stack Development, watch this video & plan accordingly. \n\nSubscribe to our channel & enjoy learning at ease.\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career as Full Stack Developer with Globally recognized Certification.\n\nBenefits of Zen class - Full Stack Development Program\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry-recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3rBNtVK\n\n#fullstack #fullstackdeveloper #frontend #fullstackdevelopment #zenclass #guvi #java #python #mysql #html #javascript #whatisfullstack #fullstackwebdevelopment #fullstackdevelopment #career #job',
#   'Tags': ['Full Stack Developer',
#    'Full Stack',
#    'Front end',
#    'Back end',
#    'Duration to learn Full Stack Development',
#    'Full Stack Course',
#    'HTML',
#    'JavaScript',
#    'Java'],
#   'PublishedAt': '2021-07-26T11:00:09Z',
#   'View_Count': '3350',
#   'Like_Count': '89',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT2M30S',
#   'Thumbnail': 'https://i.ytimg.com/vi/XjxdD2xn4GQ/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'QEuNaZmbKhs',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'What is Full Stack Development? | Zen Class Q&A Series',
#   'Video_Description': 'Become a Full Stack Developer in 90 days - https://bit.ly/3rtArK7\n\nIntroducing Zen Class Q&A series on Full Stack Development. In this video, Mr Arun Prakash, Founder & COO - GUVI, will explain to you in detail about "What is Full Stack Development?" or "What is Full Stack?".\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career as Full Stack Developer with Globally recognized Certification.\n\nBenefits of Zen class - Full Stack Development Program\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry-recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3rtArK7\n\n#fullstack #career #job #fullstackdeveloper #frontend #fullstackdevelopment #zenclass #guvi #java #python #mysql #html #javascript #whatisfullstack #fullstackwebdevelopment #fullstackdevelopment',
#   'Tags': ['Java',
#    'JavaScript',
#    'HTML',
#    'CSS',
#    'Frontend',
#    'Backend',
#    'Full stack web developer',
#    'Full Stack',
#    'Full Stack Deveveloper',
#    'Full Stack Web Development',
#    'Full Stack Web Developer',
#    'What is Full Stack Development',
#    'What is Full Stack Web Development'],
#   'PublishedAt': '2021-07-22T10:35:56Z',
#   'View_Count': '32147',
#   'Like_Count': '145',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT3M15S',
#   'Thumbnail': 'https://i.ytimg.com/vi/QEuNaZmbKhs/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'e-0RSra-XkA',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Full Stack Development Career Guidance | Become a Full Stack Developer in 90 days',
#   'Video_Description': 'Check out Zen Class from GUVI - Full Stack Developer Program with Job Placement Support\n\nClick here - https://bit.ly/full-stack-zen\n\nIn this video, Mr Arun Prakash, Founder & COO - GUVI will explain in detail the career opportunities in Full Stack Development. Also, will help you understand the basic of Full Stack Development in an easy way.\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career with ZEN’s globally recognized Certification.\n\nBenefits of Zen class\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry-recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/full-stack-zen\n\n#fullstack #career #job #fullstackdeveloper #frontend #fullstackdevelopment #zenclass #guvi #java #python #sql',
#   'Tags': None,
#   'PublishedAt': '2021-07-16T07:36:03Z',
#   'View_Count': '11860',
#   'Like_Count': '281',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '6',
#   'Duration': 'PT1H31M1S',
#   'Thumbnail': 'https://i.ytimg.com/vi/e-0RSra-XkA/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'R2GX8Zrnkus',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Zen Placement Alert: Prashanth Palki, Full Stack Developer @ Ankercloud Technologies',
#   'Video_Description': 'Much needed boast in this tough time! \n\nHappy to announce that our ZEN student - Prashanth Palki got placed in Ankercloud Technologies as Full Stack Developer.\n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career with ZEN’s globally recognized Certification.\n\nBenefits of Zen class\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry-recognized certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3uNxC7j\n\n#fullstackdeveloper #fullstack #placement #job #coding #frontend #backend #python #java #css #html',
#   'Tags': None,
#   'PublishedAt': '2021-05-14T14:59:51Z',
#   'View_Count': '8229',
#   'Like_Count': '85',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '2',
#   'Duration': 'PT1M7S',
#   'Thumbnail': 'https://i.ytimg.com/vi/R2GX8Zrnkus/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '9C-Sp32Nx3w',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Zen Placement | Prashant Gupta, Full Stack Developer @ Saveo',
#   'Video_Description': 'Here is another placement from Zen class! \n\nPrashant Gupta placed as Full Stack Developer @ Saveo, with more than a 300% hike. \n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career with ZEN’s globally recognized Certification.\n\nBenefits of Zen class\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry- recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3rzSlJs\n\n#fullstackdeveloper\u200b #fullstack\u200b #placement\u200b #job\u200b #coding\u200b #frontend\u200b #backend',
#   'Tags': None,
#   'PublishedAt': '2021-03-29T09:35:57Z',
#   'View_Count': '11367',
#   'Like_Count': '107',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '7',
#   'Duration': 'PT5M34S',
#   'Thumbnail': 'https://i.ytimg.com/vi/9C-Sp32Nx3w/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'AHay3m1RhWw',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'Biomedical Engineer to Full Stack Developer | Zen Placement',
#   'Video_Description': 'Is it possible for Non-CS Background to become a Full Stack Developer?\n\nWe, at ZEN, will make it happen! Here is an example - Venkat (Biomedical Engineer) from the Zen class placed in a product company with a good package. \n\nStand out from billion developers with a bunch of augmented skills & Skyrocket your career with ZEN’s globally-recognized Certification.\n\nBenefits of Zen class\n✓ Proficiency in Full Stack Development with remarkable logical skills\n✓ 100% Job Placement Support\n✓ Best lucrative job in extravagant organizations\n✓ Industry- recognized Certification\n✓ Best mentorship and guidance\n\nTo enroll in Zen class, click here - https://bit.ly/3d6Ux6f\n\n#fullstackdeveloper #fullstack #placement #job #coding #frontend #backend',
#   'Tags': None,
#   'PublishedAt': '2021-03-29T09:19:04Z',
#   'View_Count': '10509',
#   'Like_Count': '76',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '17',
#   'Duration': 'PT1M8S',
#   'Thumbnail': 'https://i.ytimg.com/vi/AHay3m1RhWw/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'ohspFx-1mG4',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'ZenClass | Shruti, Full Stack Developer, Intain | Success Stories',
#   'Video_Description': 'Despite being from a testing domain, Shruti managed to shift her career to Full Stack Development with help of Zen Class.',
#   'Tags': None,
#   'PublishedAt': '2021-01-04T17:08:12Z',
#   'View_Count': '3621',
#   'Like_Count': '58',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '3',
#   'Duration': 'PT48S',
#   'Thumbnail': 'https://i.ytimg.com/vi/ohspFx-1mG4/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'grdkvg14QbA',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'ZenClass | Rohan, Full Stack Developer, Cimpress | Success Stories',
#   'Video_Description': 'A student who pursued ECE from SRM, Chennai managed to shift his career towards full stack development with ZenClass. Hear what he has to say!',
#   'Tags': None,
#   'PublishedAt': '2021-01-04T07:23:45Z',
#   'View_Count': '1270',
#   'Like_Count': '21',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M23S',
#   'Thumbnail': 'https://i.ytimg.com/vi/grdkvg14QbA/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'qNHsudFEX4o',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'ZenClass | Anil Kumar, Full Stack Developer | Success Stories',
#   'Video_Description': 'Meet Anil Kumar from the Feb 2020 Batch of Zen Class shaing his experience and thanks to his mentor & Zen Team for successful career.',
#   'Tags': None,
#   'PublishedAt': '2021-01-04T07:23:42Z',
#   'View_Count': '1130',
#   'Like_Count': '14',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M46S',
#   'Thumbnail': 'https://i.ytimg.com/vi/qNHsudFEX4o/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': 'o6GoV5dn68k',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'ZenClass | Pratyaksh, Associate Software Developer,  JusPay | Success Stories',
#   'Video_Description': 'Despite a challenging job search scenario in the Covid era, Pratyaksh managed to get a job in JusPay Technologies as a Associate Software Developer with help of Zen Class.',
#   'Tags': None,
#   'PublishedAt': '2021-01-04T07:23:39Z',
#   'View_Count': '1882',
#   'Like_Count': '17',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT1M32S',
#   'Thumbnail': 'https://i.ytimg.com/vi/o6GoV5dn68k/default.jpg',
#   'caption_status': 'false'},
#  {'Video_Id': '-0W7yiSOVX8',
#   'Channel_Name': "GUVI's Zen Class",
#   'Channel_ID': 'UCiEmtpFVJjpvdhsQ2QAhxVA',
#   'Video_Name': 'ZenClass Reviews | Krishna, Full Stack Developer | Success Stories',
#   'Video_Description': 'An ECE Engineering student got an opportunity to start his career in top product company as Full Stack Developer with help of Zen Class.',
#   'Tags': ['full stack development',
#    'zen class',
#    'guvi zen class',
#    'guvi reviews',
#    'zenclass reviews'],
#   'PublishedAt': '2021-01-04T07:23:12Z',
#   'View_Count': '2271',
#   'Like_Count': '39',
#   'Dislike_Count': None,
#   'Favorite_Count': '0',
#   'Comment_Count': '0',
#   'Duration': 'PT2M28S',
#   'Thumbnail': 'https://i.ytimg.com/vi/-0W7yiSOVX8/default.jpg',
#   'caption_status': 'false'}]

# %%
#Get comments info

def get_comments_info(Channel_ID):
    All_comment_info = []
    try:
        for c in All_Video_IDs:
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=c,
                maxResults = 50
            )
            response = request.execute()

            for results in response['items']:
                d3 = dict(Comment_Id_1 = results['snippet']['topLevelComment']['id'],
                        video_Id = results['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text = results['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author = results['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_PublishedAt = results['snippet']['topLevelComment']['snippet']['publishedAt']
                        )
                
                All_comment_info.append(d3)
                
    except:
        pass
    return All_comment_info

# %%
c = get_comments_info("UCFdNVWyDVrVUpTb-2SlDFqg")

# %%
c
# Out:
# [{'Comment_Id_1': 'UgzSpli9wKZSsl9jkFR4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Feyd Rautha, Feyd Rautha, Feyd Rautha! FEYD RAUTHA, FEYD RAUTHA!!! 🔥',
#   'Comment_Author': '@hvip4',
#   'Comment_PublishedAt': '2024-04-13T21:28:16Z'},
#  {'Comment_Id_1': 'UgyygnOMJyiBdcxmsPt4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'The only strong character in the movie and he got killed 😕 Utterly disappointing. He should have killed Paul, the Emperor, his uncle, and the witches (obviously), then ruled as the new Emperor. Alas, he had a thing for women 😁 Men… 🙄',
#   'Comment_Author': '@claudiamanta1943',
#   'Comment_PublishedAt': '2024-04-13T20:33:16Z'},
#  {'Comment_Id_1': 'Ugy8UtLTbPrTUGRaffR4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'why every girl loves him ?',
#   'Comment_Author': '@AlvinREDDELTA',
#   'Comment_PublishedAt': '2024-04-13T00:07:55Z'},
#  {'Comment_Id_1': 'Ugw0uJZOkFCpygxcrot4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'я думал этому актеру лет 20',
#   'Comment_Author': '@user-eb7xs4wj2r',
#   'Comment_PublishedAt': '2024-04-12T20:16:38Z'},
#  {'Comment_Id_1': 'UgysJ-tYoWxdj7RX1iJ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'In book and original movie he had no honor. In the fight between him and Paul he tried using a poisoned blade',
#   'Comment_Author': '@Bigdan678',
#   'Comment_PublishedAt': '2024-04-12T18:19:43Z'},
#  {'Comment_Id_1': 'UgyNRLP-nFw9euVajHR4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': '&quot;May thy knife chip and chatter&quot;<br>Paul and Feyd',
#   'Comment_Author': '@milutinstankovic4638',
#   'Comment_PublishedAt': '2024-04-12T17:59:09Z'},
#  {'Comment_Id_1': 'Ugz7rMmNkhwnF52QUlZ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'I am SO sad that we only got to see so little of Austin as Feyd. He stole the show!<br>I&#39;d totally watch an entire movie just about him. <br>Someone give that man an award!',
#   'Comment_Author': '@lunaire1106',
#   'Comment_PublishedAt': '2024-04-12T17:54:55Z'},
#  {'Comment_Id_1': 'UgzfAsdcUb2iECkW1Y14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'I dont know if this is too much to ask but I&#39;m trying to convince someone to watch the Clone Wars but without spoiling anything huge. I&#39;ve tried looking for a trailer for the whole show but there&#39;s nothing. Idk if its possible for you to make a fan trailer for the whole show. I dont mind if it spoils a bit. I just need this person to watch it. Ive been asking for months.',
#   'Comment_Author': '@a.chris99',
#   'Comment_PublishedAt': '2024-04-12T16:05:48Z'},
#  {'Comment_Id_1': 'UgxAKYS1QGQDc9v_Bl54AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'I wish he would have survived longer and played an important role in Paul&#39;s Jihad ... he had so much potential, in the books, too. Herbert killed him off too soon in my opinion. The dynamic both could have had ... Cousins who were meant to be married, if Jessica didn&#39;t decide to have boy instead of a girl, and Feyd would have had sooo much respect for Paul, even admired him a bit and he&#39;d be so fascinated by him as a leading figure, while being a serious threat himself. <br>There&#39;s so much potential',
#   'Comment_Author': '@Felarof245',
#   'Comment_PublishedAt': '2024-04-12T13:16:34Z'},
#  {'Comment_Id_1': 'UgyHqXR1qIaVeOB6cdJ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Whose voice at the beginning? Sounds cool af',
#   'Comment_Author': '@AtectD',
#   'Comment_PublishedAt': '2024-04-12T09:01:42Z'},
#  {'Comment_Id_1': 'UgyahZcuNI7W7mF9Wgx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Want to see this with Sting from Dune 1984, lol',
#   'Comment_Author': '@spaceetc2436',
#   'Comment_PublishedAt': '2024-04-12T06:50:18Z'},
#  {'Comment_Id_1': 'Ugyc9xabuyqC-6qyGNx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'OMG The power and pressure... Incredible/////please give me like.... an full season show of Feyd.....or just all about the House Harkonnen...',
#   'Comment_Author': '@duetdubelav9965',
#   'Comment_PublishedAt': '2024-04-12T04:48:10Z'},
#  {'Comment_Id_1': 'UgwRR3pRCjRb79eNuIt4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'i believe in miracles!  where you from, you sexy thing?',
#   'Comment_Author': '@Ipsifendis',
#   'Comment_PublishedAt': '2024-04-12T04:25:01Z'},
#  {'Comment_Id_1': 'UgwmUpzYv4XVR80yW1t4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Great edit. Only thing holding it back is the music, since it&#39;s a bit generic, and lacks connection to the music of the movie.',
#   'Comment_Author': '@jmwhiting',
#   'Comment_PublishedAt': '2024-04-12T03:51:23Z'},
#  {'Comment_Id_1': 'UgwMa1siPMdjwoU3lzN4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': '<i>Agùm beıd-baūn Feyd Rautha...</i><br><b><i>...kïdò Platfi Gemāzeı Arrakīs!</i></b>',
#   'Comment_Author': '@cloudy7937',
#   'Comment_PublishedAt': '2024-04-12T03:29:01Z'},
#  {'Comment_Id_1': 'Ugw9jSki6D8Jl7JzuPh4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Austin Butler stole the movie with only 16 minutes screen time. His aura and charisma as Feyd obliterated everything when he was on the screen. Such an outstanding character! He is truly my hero! I mean my villain 😉❤',
#   'Comment_Author': '@seagiven404',
#   'Comment_PublishedAt': '2024-04-12T01:43:02Z'},
#  {'Comment_Id_1': 'UgyeqyGK555yAI1fuKx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'From redhead to bald.',
#   'Comment_Author': '@pacoramon9468',
#   'Comment_PublishedAt': '2024-04-11T23:45:38Z'},
#  {'Comment_Id_1': 'UgzM1STTgZGEsjD48r54AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Kind of a skimmed over character tbf',
#   'Comment_Author': '@user-mf5co7gh6j',
#   'Comment_PublishedAt': '2024-04-11T23:41:24Z'},
#  {'Comment_Id_1': 'Ugy1B2dn9Chxsf7XuLZ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'The music in this makes it seems like he&#39;s the hero',
#   'Comment_Author': '@judsonjean-pierre1804',
#   'Comment_PublishedAt': '2024-04-11T22:07:27Z'},
#  {'Comment_Id_1': 'UgwqLijVbDqQT3GrPJl4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': '🖤🤍🖤',
#   'Comment_Author': '@evanyvltova28',
#   'Comment_PublishedAt': '2024-04-11T21:40:25Z'},
#  {'Comment_Id_1': 'UgzlM52V-6-_zfZtAaN4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Im obsessed with the language of the Harkonnens, if feels like german, latin and japanese mixed into one... It sounds so good 🤧🤧',
#   'Comment_Author': '@angxl2023',
#   'Comment_PublishedAt': '2024-04-11T21:16:54Z'},
#  {'Comment_Id_1': 'Ugxc65CQhTPKTwzw52R4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Most impressive actor to come along since Brando and Daniel Day Lewis.....truly amaqzing...you GO Austin!',
#   'Comment_Author': '@ruthnagarya2028',
#   'Comment_PublishedAt': '2024-04-11T21:08:27Z'},
#  {'Comment_Id_1': 'UgxJddHyUM1adtzojyJ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'so in love with him, im sad we wont see him again :(',
#   'Comment_Author': '@astarionposting',
#   'Comment_PublishedAt': '2024-04-11T21:06:40Z'},
#  {'Comment_Id_1': 'UgzPeVTBrERrF3z07TV4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Absolutely masterful work on this one, my friend! Austin Butler&#39;s Feyd-Rautha is a perfect portrayal of everything the Harkonnens stand for on film. Your editing here is flawless and I cannot wait for more, mate!',
#   'Comment_Author': '@filmfandom',
#   'Comment_PublishedAt': '2024-04-11T20:59:19Z'},
#  {'Comment_Id_1': 'UgzYrzLyizwWWNvPLDN4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Amazing',
#   'Comment_Author': '@filmsbyhen',
#   'Comment_PublishedAt': '2024-04-11T20:59:08Z'},
#  {'Comment_Id_1': 'UgwsG_bTq4ggYCkcTKx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Best character of the film',
#   'Comment_Author': '@davidfernandez9791',
#   'Comment_PublishedAt': '2024-04-11T20:25:12Z'},
#  {'Comment_Id_1': 'UgwD2DX05AhOkQJ8HFh4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'So do like harkonnens have no eyebrows?',
#   'Comment_Author': '@internallyscreaming2788',
#   'Comment_PublishedAt': '2024-04-11T20:11:16Z'},
#  {'Comment_Id_1': 'UgxAeH7SUDnF3QcperV4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Perfect movie!',
#   'Comment_Author': '@escorpio5911',
#   'Comment_PublishedAt': '2024-04-11T20:09:48Z'},
#  {'Comment_Id_1': 'Ugy3JWq2yUqI1J43OKN4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'I will welcome his blade...',
#   'Comment_Author': '@cristianali9976',
#   'Comment_PublishedAt': '2024-04-11T19:59:01Z'},
#  {'Comment_Id_1': 'Ugw52KVzErtEOyg-b0h4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'You really needed to insert this spoiler at the end?',
#   'Comment_Author': '@Diogenes-jn7nh',
#   'Comment_PublishedAt': '2024-04-11T19:57:41Z'},
#  {'Comment_Id_1': 'UgxFpI3xMx7wPbIMNCx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'I need a 3hr movie with Austin Butler as Feyd. He was ungodly good in every scene.',
#   'Comment_Author': '@phantom213',
#   'Comment_PublishedAt': '2024-04-11T19:43:03Z'},
#  {'Comment_Id_1': 'UgxRSDXzcw3viudRhdl4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'The power he radiates everytime he was on screen was breathtaking. Austin Butler was a perfect casting choice.',
#   'Comment_Author': '@letsplaygaming714',
#   'Comment_PublishedAt': '2024-04-11T19:35:30Z'},
#  {'Comment_Id_1': 'UgxmZDJ52bIb6rTZ3Wh4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Where did you get the scenes ?',
#   'Comment_Author': '@cathygalstyan',
#   'Comment_PublishedAt': '2024-04-11T19:26:24Z'},
#  {'Comment_Id_1': 'Ugwh-2tB7pxqaP7Ixf14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'The north is liberated and secure.... Harvest spice at will',
#   'Comment_Author': '@Kyleforthe3SIKE',
#   'Comment_PublishedAt': '2024-04-11T19:25:16Z'},
#  {'Comment_Id_1': 'UgxYkcds8_pVD2aEdJ14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'The edit is TIP TOP. <br><br>Instant sub.',
#   'Comment_Author': '@DESSERT_X',
#   'Comment_PublishedAt': '2024-04-11T19:02:36Z'},
#  {'Comment_Id_1': 'Ugx27Gp90v8DQDvqq2Z4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'is this Halland but bald.',
#   'Comment_Author': '@rushtuts',
#   'Comment_PublishedAt': '2024-04-11T18:27:56Z'},
#  {'Comment_Id_1': 'UgwHfsFw00dsbMeiHRN4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Wish he was in a bit more he was soo cool.',
#   'Comment_Author': '@leonpetrichiutto1152',
#   'Comment_PublishedAt': '2024-04-11T18:15:11Z'},
#  {'Comment_Id_1': 'UgzsqSAOvvFlv87s-bl4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'He&#39;s insane',
#   'Comment_Author': '@leonpetrichiutto1152',
#   'Comment_PublishedAt': '2024-04-11T18:12:07Z'},
#  {'Comment_Id_1': 'Ugz6n6d25cFw7ZovBvF4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Love it bro, perfect cute and the music fits so well. You are consistently delivering greatness',
#   'Comment_Author': '@panosdks',
#   'Comment_PublishedAt': '2024-04-11T17:56:12Z'},
#  {'Comment_Id_1': 'Ugws7MRHdhQbA6tY7A14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'He was a monstrous savage, but there was something more layered to him.<br><br>He respected Paul and gave him a fair duel, smiled at the Fremen quotation and enjoyed an honest fight.',
#   'Comment_Author': '@jonbaxter2254',
#   'Comment_PublishedAt': '2024-04-11T17:51:20Z'},
#  {'Comment_Id_1': 'Ugxi2hwgr3XSEjM9F854AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Another excellent edit. Your understanding of theme and characterization is always so present in your videos, it&#39;s truly a joy to watch. Keep up the great work my friend!',
#   'Comment_Author': '@noahclark3285',
#   'Comment_PublishedAt': '2024-04-11T17:47:36Z'},
#  {'Comment_Id_1': 'UgxI2Hn95cw-MkaLuv14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Sweet',
#   'Comment_Author': '@shanenolan5625',
#   'Comment_PublishedAt': '2024-04-11T17:42:22Z'},
#  {'Comment_Id_1': 'UgxR4_N2oVO_KOS1NPh4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'love ur star war edits. not sure about the &#39;heroic&#39; feel of this one. feyd was the baddie.',
#   'Comment_Author': '@jesseb4503',
#   'Comment_PublishedAt': '2024-04-11T17:10:19Z'},
#  {'Comment_Id_1': 'UgwiW3d9jbfE6fmurNB4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'His presentation in the coliseum is the best scene in the movie.',
#   'Comment_Author': '@rockito_.',
#   'Comment_PublishedAt': '2024-04-11T17:09:45Z'},
#  {'Comment_Id_1': 'UgxF5HZoCz6yc2U2wWJ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'So well done! Bravo!',
#   'Comment_Author': '@pedallove7058',
#   'Comment_PublishedAt': '2024-04-11T17:02:32Z'},
#  {'Comment_Id_1': 'UgwuUyNwZhSt5x8rEJZ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'When the villain is more likable then the hero',
#   'Comment_Author': '@Loner-Wolf',
#   'Comment_PublishedAt': '2024-04-11T16:56:18Z'},
#  {'Comment_Id_1': 'UgxqrVXkV9z5SEWpdWV4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'So this albino guy is the real hero of Dune2. 😂😂😂😢😢😢😮😮😮😅😅😅',
#   'Comment_Author': '@thisismyname007',
#   'Comment_PublishedAt': '2024-04-11T16:52:07Z'},
#  {'Comment_Id_1': 'UgyVu08Azd_Oeko95jJ4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Why is bald austin butler always on my mind',
#   'Comment_Author': '@uraddiictOnx3',
#   'Comment_PublishedAt': '2024-04-11T16:36:30Z'},
#  {'Comment_Id_1': 'UgzdFMus2qAeJl4N2s14AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Now, only pleasure remains.',
#   'Comment_Author': '@VictorIV0310',
#   'Comment_PublishedAt': '2024-04-11T16:26:25Z'},
#  {'Comment_Id_1': 'UgzQN2oKfly1_hFEJyx4AaABAg',
#   'video_Id': 'bYpHtW8KSqg',
#   'Comment_Text': 'Amazing as always. We want montage about Chani!',
#   'Comment_Author': '@antres.8096',
#   'Comment_PublishedAt': '2024-04-11T16:25:17Z'},
#  {'Comment_Id_1': 'UgxQTQGeKbkD1j6EOoB4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'What an edit wwwwwwwooooooow  !!',
#   'Comment_Author': '@Wi11liamMunny',
#   'Comment_PublishedAt': '2024-04-14T07:52:01Z'},
#  {'Comment_Id_1': 'Ugy5MaDXjauBfbjPZKx4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'I’ve grown to idolize Paul for the values he embodies in the film. They really went off on this one',
#   'Comment_Author': '@DesolateRind',
#   'Comment_PublishedAt': '2024-04-13T19:31:36Z'},
#  {'Comment_Id_1': 'UgykFYGgSfVUx5v69cB4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'insane edit',
#   'Comment_Author': '@barafohlova6122',
#   'Comment_PublishedAt': '2024-04-13T13:57:49Z'},
#  {'Comment_Id_1': 'UgzaR59P9d9xeeJ-Ryp4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'You produce the ultimate power and then you assume you&#39;re able to control it? Who&#39;s the naive one here?',
#   'Comment_Author': '@immortaljanus',
#   'Comment_PublishedAt': '2024-04-13T06:24:16Z'},
#  {'Comment_Id_1': 'Ugx9J_P9Lv69NlISSe54AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'So many better edits out there',
#   'Comment_Author': '@hogwash1146',
#   'Comment_PublishedAt': '2024-04-13T00:34:02Z'},
#  {'Comment_Id_1': 'UgwkzkvTQdfv9sLT22F4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Dune just destroyed star wars franchise.',
#   'Comment_Author': '@nicoledreamcr4666',
#   'Comment_PublishedAt': '2024-04-12T16:05:55Z'},
#  {'Comment_Id_1': 'UgyCirvuT3v4ipyDK_F4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'NICE WORK BRO!',
#   'Comment_Author': '@ADedits9',
#   'Comment_PublishedAt': '2024-04-11T22:40:31Z'},
#  {'Comment_Id_1': 'Ugz9xO0apj4DK8SH3eR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Tributes with Lyrics can motivate you but a perfectly timed instrumental tuned to its Visuals is something time cannot touch because you can watch it a million times and it will still invoke something beautiful. Well done 👍🏽',
#   'Comment_Author': '@lukewhatidid1735',
#   'Comment_PublishedAt': '2024-04-11T18:01:56Z'},
#  {'Comment_Id_1': 'Ugx_xtcD-niihksycGl4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Love the edit !! Could you maybe tell me how you get the clips to edit in such a good quality ? Are you simply screen recording a streaming site or what ? anyways thanks a lot !',
#   'Comment_Author': '@sky.441',
#   'Comment_PublishedAt': '2024-04-11T17:37:31Z'},
#  {'Comment_Id_1': 'UgyLnt7xmHjDzXbo2-p4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'ZOMG. I just got chills all down my spine watching this. Thank you ♥',
#   'Comment_Author': '@iamfinky',
#   'Comment_PublishedAt': '2024-04-11T14:00:07Z'},
#  {'Comment_Id_1': 'UgyV24j6rwBTqdtBppN4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Hey man. How do you get your videos to be uploaded like this? Its already full screen without full screening it',
#   'Comment_Author': '@Kanoez',
#   'Comment_PublishedAt': '2024-04-11T13:29:40Z'},
#  {'Comment_Id_1': 'UgzKaGloAHBNEZ9qiZR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=WaSY701eXSU&amp;t=131">2:11</a> Rhóxax xaqha! Yhó xpyq txa qhað!',
#   'Comment_Author': '@purgruv',
#   'Comment_PublishedAt': '2024-04-11T11:58:03Z'},
#  {'Comment_Id_1': 'Ugxm73mW46QsFKNxjPR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'banger video, so excited for dune messiah',
#   'Comment_Author': '@MrTrouserpants101',
#   'Comment_PublishedAt': '2024-04-11T09:03:05Z'},
#  {'Comment_Id_1': 'Ugwc2plErk5uAjBZ32t4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Masterpiece!!!! Bravo!!!',
#   'Comment_Author': '@criticalmas7770',
#   'Comment_PublishedAt': '2024-04-11T08:33:00Z'},
#  {'Comment_Id_1': 'UgxIK0I031aPkITGgJd4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'so...can a t girl be a bene gen ?',
#   'Comment_Author': '@RADIOSTATIONFUTUREHITS2024',
#   'Comment_PublishedAt': '2024-04-11T06:40:35Z'},
#  {'Comment_Id_1': 'Ugw2Vl7JbZsqX_ezqjt4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Beautifully edited, more than beautiful. Expresses the story we can fit in with love and education. Our imaginations can be a gateway to multiple of worlds we choose to live in. That is one of them in mine, I do hope everyone else could see it as well.',
#   'Comment_Author': '@gtaipan7422',
#   'Comment_PublishedAt': '2024-04-11T06:19:43Z'},
#  {'Comment_Id_1': 'Ugx0gPYK79AMNCyJfQt4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Sometimes time itself controls everything, something even the Bene Gesserit are unable to reach.',
#   'Comment_Author': '@gtaipan7422',
#   'Comment_PublishedAt': '2024-04-11T06:09:07Z'},
#  {'Comment_Id_1': 'UgygFPpvWns3PdQhFtp4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'One of the MAJOR themes of Dune is one is never as in control as you think you are, and that unexpected events can blindside you despite literal millennia of preparation.',
#   'Comment_Author': '@SanosEdge',
#   'Comment_PublishedAt': '2024-04-11T05:23:57Z'},
#  {'Comment_Id_1': 'UgzeTIFKFbbUpMdEqbR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Brilliant, as always.',
#   'Comment_Author': '@talentedmrcollins4923',
#   'Comment_PublishedAt': '2024-04-11T03:55:50Z'},
#  {'Comment_Id_1': 'UgxCzzJ6PK-OQzJHGCR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Hi OP<br><br>Have I mentioned how awesome it is that in those smaller Character Study videos you always put up a DUNE prologue line with the Sadukkar throat language? ❤<br><br>(Tho I wouldn’t be surprised if the audios are always the same one 😂🎉)',
#   'Comment_Author': '@davidw.2791',
#   'Comment_PublishedAt': '2024-04-11T02:32:26Z'},
#  {'Comment_Id_1': 'Ugy3SdaQTlCX8UQT04B4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'amazing edit !',
#   'Comment_Author': '@aegnor2102',
#   'Comment_PublishedAt': '2024-04-11T01:32:27Z'},
#  {'Comment_Id_1': 'UgzZPTylzp3oS5e72Wx4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'We do not hope. We plan.',
#   'Comment_Author': '@VictorIV0310',
#   'Comment_PublishedAt': '2024-04-11T00:52:57Z'},
#  {'Comment_Id_1': 'UgwfG2rTQOkk-qlBxJV4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'You play with fire, you get burned.<br><br>The Bene Gesserit, in their arrogance, thought they could control what they started. And now they have to deal with the inferno they started.',
#   'Comment_Author': '@leehaber',
#   'Comment_PublishedAt': '2024-04-11T00:47:53Z'},
#  {'Comment_Id_1': 'UgyzYiDu59WPkAA9b1x4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Secret organizations, like the Bene Gesserit, have no sides because they control all sides in the game they have built for millennia.',
#   'Comment_Author': '@ryankwon8785',
#   'Comment_PublishedAt': '2024-04-10T23:02:08Z'},
#  {'Comment_Id_1': 'UgxxTV6mb7_qcuFqyap4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Beautifully cut and put together clip. Thank You.',
#   'Comment_Author': '@cyprian_3823',
#   'Comment_PublishedAt': '2024-04-10T22:20:18Z'},
#  {'Comment_Id_1': 'UgxHu9R9hSN42tHXQ1t4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Increíble! Pure brilliance!',
#   'Comment_Author': '@christiangonzalezify',
#   'Comment_PublishedAt': '2024-04-10T21:52:05Z'},
#  {'Comment_Id_1': 'UgwXuoIZYsLOegve6-J4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'art',
#   'Comment_Author': '@hello-4229',
#   'Comment_PublishedAt': '2024-04-10T21:32:37Z'},
#  {'Comment_Id_1': 'Ugw6obxbJUgZ6igPWZd4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Your stuff is just amazing! <br>Can&#39;t wait for more Dune edits',
#   'Comment_Author': '@kamilslaby_',
#   'Comment_PublishedAt': '2024-04-10T21:31:24Z'},
#  {'Comment_Id_1': 'UgwBlokuRQ-Cx5OjkMN4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Does it bug anyone else that she says a form of power that our &#39;&#39;world&#39;&#39; has not yet seen? Don&#39;t they live on many worlds? Perhaps a faux pas by Frank Herbert or the screenplay writer for Dune 2024.',
#   'Comment_Author': '@JoshuaTozer',
#   'Comment_PublishedAt': '2024-04-10T21:22:22Z'},
#  {'Comment_Id_1': 'UgzTfEWyZD2DtwHV-Tp4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'And the most funny thing of all: The Bene Gesserit will survive the millenia long span of Herberts books - and in the end, they will rule the empire...',
#   'Comment_Author': '@Ferox2121',
#   'Comment_PublishedAt': '2024-04-10T20:58:52Z'},
#  {'Comment_Id_1': 'Ugwoj5T2VjRcCTzEE5h4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Your work here is amazing, my friend! 🔥🔥',
#   'Comment_Author': '@filmfandom',
#   'Comment_PublishedAt': '2024-04-10T20:27:36Z'},
#  {'Comment_Id_1': 'UgwDOB_2TkLOF88LOSp4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Fear Is the Mind Killer 🗣️🥷🏽',
#   'Comment_Author': '@davidlozano4507',
#   'Comment_PublishedAt': '2024-04-10T18:41:58Z'},
#  {'Comment_Id_1': 'UgxpAGmCWAgYeJi7WKd4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Only I Will Remain 🗣️🦹🏼\u200d♀️',
#   'Comment_Author': '@davidlozano4507',
#   'Comment_PublishedAt': '2024-04-10T18:41:38Z'},
#  {'Comment_Id_1': 'UgxKyK7-V_lWtlX3JBl4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'The Holy War Begins🤺🪐',
#   'Comment_Author': '@davidlozano4507',
#   'Comment_PublishedAt': '2024-04-10T18:40:59Z'},
#  {'Comment_Id_1': 'Ugy6w6pu0lCb6eSntGp4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': '&quot;SILENCE!!!!!&quot;',
#   'Comment_Author': '@thestanleys3657',
#   'Comment_PublishedAt': '2024-04-10T18:32:16Z'},
#  {'Comment_Id_1': 'UgwTvtkwmoZc_LBDWQR4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Very happy we are getting a bene gesserit show, they are so cool',
#   'Comment_Author': '@timelord2502',
#   'Comment_PublishedAt': '2024-04-10T18:02:19Z'},
#  {'Comment_Id_1': 'Ugxoq8vPURFlBhF3HfJ4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@percyweasley9301',
#   'Comment_PublishedAt': '2024-04-10T17:41:04Z'},
#  {'Comment_Id_1': 'UgwxgLeVUqZEBB2ZkI14AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Awesome',
#   'Comment_Author': '@mr.nobody1384',
#   'Comment_PublishedAt': '2024-04-10T17:32:01Z'},
#  {'Comment_Id_1': 'UgyccyA622wPEy2RxVx4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'PLEASE make a video about Feyd Rautha! That character was just insane!',
#   'Comment_Author': '@nilocblue',
#   'Comment_PublishedAt': '2024-04-10T17:10:23Z'},
#  {'Comment_Id_1': 'UgzNe811NlzSeM-glDt4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'You will see. The beauty and the horror.',
#   'Comment_Author': '@TheTheologyProfessor',
#   'Comment_PublishedAt': '2024-04-10T17:09:27Z'},
#  {'Comment_Id_1': 'UgzMvaU9rZqg9OABPbt4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Consider what you are about to do Paul Atreides<br>Paul: <b>S I L E N C E !</b>',
#   'Comment_Author': '@dbz9393',
#   'Comment_PublishedAt': '2024-04-10T17:08:36Z'},
#  {'Comment_Id_1': 'Ugwlei8MnJUjsHhlz_d4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Absolutely incredible my friend!',
#   'Comment_Author': '@HZEditsYT',
#   'Comment_PublishedAt': '2024-04-10T17:06:44Z'},
#  {'Comment_Id_1': 'UgwqfBQVRU_vYnSDlWN4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'You had me with the title',
#   'Comment_Author': '@shanenolan5625',
#   'Comment_PublishedAt': '2024-04-10T16:40:03Z'},
#  {'Comment_Id_1': 'UgzCFsyKodRjU43Z04t4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'The Witches who wear only black, arrive at the exact time when Total Solar Eclipse happens. <br>Black Moon. Black Sun. Black Sky.  🖤',
#   'Comment_Author': '@DESSERT_X',
#   'Comment_PublishedAt': '2024-04-10T16:37:20Z'},
#  {'Comment_Id_1': 'UgySc1G_VTC2ifrn5td4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Never ceases to amaze me! Well down SWFT! I honestly find the Bene Gesserit interesting in both the books and movies! Especially with their ties to the Great Houses',
#   'Comment_Author': '@loganhaslam286',
#   'Comment_PublishedAt': '2024-04-10T16:29:09Z'},
#  {'Comment_Id_1': 'Ugw7rW6Y_QryMyeiXDt4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Amazing edit as usual. Good job.',
#   'Comment_Author': '@erencankara6857',
#   'Comment_PublishedAt': '2024-04-10T16:26:53Z'},
#  {'Comment_Id_1': 'UgyMF9AYKMvh6aiXZsZ4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Absolutely amazing man',
#   'Comment_Author': '@AlvarCreations',
#   'Comment_PublishedAt': '2024-04-10T16:24:53Z'},
#  {'Comment_Id_1': 'Ugz-tSaJeKRUil062t14AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'Lead them to paradise',
#   'Comment_Author': '@1gbuzzin',
#   'Comment_PublishedAt': '2024-04-10T16:17:57Z'},
#  {'Comment_Id_1': 'UgwwzOAN4ex8y4ELQHV4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'LISAN AL GAIIB!!!',
#   'Comment_Author': '@squirellplays4187',
#   'Comment_PublishedAt': '2024-04-10T16:16:26Z'},
#  {'Comment_Id_1': 'Ugx8RcMJouiXsfvTWSB4AaABAg',
#   'video_Id': 'WaSY701eXSU',
#   'Comment_Text': 'The Palaptines of Dune',
#   'Comment_Author': '@Quantoffo',
#   'Comment_PublishedAt': '2024-04-10T16:15:08Z'},
#  {'Comment_Id_1': 'UgxbgU5VQagj9VivbT54AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Beautiful edit!',
#   'Comment_Author': '@arpitjain2591',
#   'Comment_PublishedAt': '2024-04-12T21:34:16Z'},
#  {'Comment_Id_1': 'Ugx9YtYRRZe0q-UHFKN4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'The Chinese hitting different for some reason.',
#   'Comment_Author': '@markkaroo',
#   'Comment_PublishedAt': '2024-04-11T22:03:14Z'},
#  {'Comment_Id_1': 'Ugz0U4fjUJSBXrwPCPJ4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'this is master piece!',
#   'Comment_Author': '@ivanyang2022',
#   'Comment_PublishedAt': '2024-04-10T13:28:24Z'},
#  {'Comment_Id_1': 'UgxTJF-IE8IcK-Z-ZAV4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Hey, i watched the series about a week ago and i must say, youre edit to it is really good! You always make good edits esspecially the one with star wars. Really made mr go more into the Empire and stay loyal to it! luke skywalker was a terrorist! LONG LIVE THE EMPIRE',
#   'Comment_Author': '@galilelollel9658',
#   'Comment_PublishedAt': '2024-04-09T14:03:42Z'},
#  {'Comment_Id_1': 'Ugx-b6xhC7N9EE_387x4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'This should have been the trailer! I lowkey want to get a Netflix sub just for this now...',
#   'Comment_Author': '@ardroniouskath',
#   'Comment_PublishedAt': '2024-04-08T03:21:59Z'},
#  {'Comment_Id_1': 'UgzCCJgCyphq22dP-tZ4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'What an amazing montage',
#   'Comment_Author': '@Damien420',
#   'Comment_PublishedAt': '2024-04-07T05:55:49Z'},
#  {'Comment_Id_1': 'UgyWxhz03764iy2Ype54AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'These are so awesome! You should have a lot more subscribers!<br>A montage on Qui Gon would be cool, but maybe hard with the limited footage.',
#   'Comment_Author': '@cvexreos',
#   'Comment_PublishedAt': '2024-04-06T21:45:05Z'},
#  {'Comment_Id_1': 'Ugxh7f9Nbe72Id9RZQl4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Amazing edit. Loved it.',
#   'Comment_Author': '@GreenBuggGaming',
#   'Comment_PublishedAt': '2024-04-06T13:00:33Z'},
#  {'Comment_Id_1': 'UgyKDgqyQXKotTISjxZ4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'This montage captures the spirit of both the series and the original novel.',
#   'Comment_Author': '@andrewlim9345',
#   'Comment_PublishedAt': '2024-04-06T03:15:46Z'},
#  {'Comment_Id_1': 'UgwMryRxlU9p03cr5mp4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Great clip. Sadly, the series itself isn&#39;t as epic',
#   'Comment_Author': '@arseniix',
#   'Comment_PublishedAt': '2024-04-05T23:34:58Z'},
#  {'Comment_Id_1': 'UgzD8gtSEUDSOffDajh4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Where is the voiceover at the start from ?',
#   'Comment_Author': '@Mateo-pq9xy',
#   'Comment_PublishedAt': '2024-04-05T23:24:04Z'},
#  {'Comment_Id_1': 'UgxOE8XlbfsgfccJWgp4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Amazing show amazing edit',
#   'Comment_Author': '@longling194',
#   'Comment_PublishedAt': '2024-04-05T23:22:36Z'},
#  {'Comment_Id_1': 'UgxcoV3AjzjtfZGEDsF4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Amazing edit and I loved that it focused on the very notable human factor in the story. Particularly the singular choice which caused everything, made by a woman absolutely broken by her entire world. The story is a tale of dread not just because it is about Aliens coming to claim Earth and how insignificant we are in comparison, but because of the humanity and what we know people would be capable of if pushed to a limit. Choosing to allow an Alien race which you have been told is evil to claim your own world because you know that it could never beat what humanity has done to you... that is just so incredibly tragic. But the tragedy isn&#39;t what makes it terrifying, it&#39;s the fact that we understand. The fact that we all know there are more people than we&#39;d like there to be who would do just the same and the fact that most of us understand their motivations if they would. It&#39;s not just the idea of the dark unknown forces beyond that keep us awake at night. It is the fact that we know there are way more people that would do the same thing as the woman. And maybe even more so... that we instinctively understand these people are not the real villains at all...',
#   'Comment_Author': '@OwlTide163',
#   'Comment_PublishedAt': '2024-04-05T21:47:19Z'},
#  {'Comment_Id_1': 'Ugzlyuxv1YitP10W7314AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'These books were unbelievably fantastic. <br><br>It absolutely terrified me. Book two was dread manifest.',
#   'Comment_Author': '@jonbaxter2254',
#   'Comment_PublishedAt': '2024-04-05T19:02:36Z'},
#  {'Comment_Id_1': 'UgwLA7GKG1Vmsy3BuT94AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Congratulations, if your goal was to make people want to watch this show, you succeeded ^^',
#   'Comment_Author': '@0RY0N',
#   'Comment_PublishedAt': '2024-04-05T18:52:27Z'},
#  {'Comment_Id_1': 'UgwQaiShAm9evmQ0W794AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Amazing show for sleeping 😴',
#   'Comment_Author': '@roshinvarghese6879',
#   'Comment_PublishedAt': '2024-04-05T18:26:37Z'},
#  {'Comment_Id_1': 'UgxSMREjAMTtGTMsK8d4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Great edit and it looks like a great show. Is it based on the &quot;Trisolaris&quot; Triologie? It quite looks so, even though Im not that far in the book.',
#   'Comment_Author': '@letsplaygaming714',
#   'Comment_PublishedAt': '2024-04-05T18:21:13Z'},
#  {'Comment_Id_1': 'Ugya7Gf506LCKdrqjTZ4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'I am ready for season two',
#   'Comment_Author': '@mardigrasking5456',
#   'Comment_PublishedAt': '2024-04-05T18:04:06Z'},
#  {'Comment_Id_1': 'Ugzlj0fFb5HXpX8zK3d4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'I’ve never heard of the movie or series but what a great edit',
#   'Comment_Author': '@Bigdan678',
#   'Comment_PublishedAt': '2024-04-05T17:35:02Z'},
#  {'Comment_Id_1': 'UgxQUx-g_n7mISiF2zZ4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Amazing work my friend!',
#   'Comment_Author': '@JesseJr19',
#   'Comment_PublishedAt': '2024-04-05T16:11:46Z'},
#  {'Comment_Id_1': 'UgyYg8XBjKzumSs5p2Z4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'Cool',
#   'Comment_Author': '@shanenolan5625',
#   'Comment_PublishedAt': '2024-04-05T16:04:52Z'},
#  {'Comment_Id_1': 'UgxLoWbeJ9wws4-hGil4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'I just finished the show yesterday... It had amazing storytelling',
#   'Comment_Author': '@Legend_editx',
#   'Comment_PublishedAt': '2024-04-05T15:59:14Z'},
#  {'Comment_Id_1': 'UgwwEh-Gnk5Q7Ymx8Lp4AaABAg',
#   'video_Id': 'Rm-TP3YvSE8',
#   'Comment_Text': 'WOW!!! What an edit!! amazing work!',
#   'Comment_Author': '@Daddynegan',
#   'Comment_PublishedAt': '2024-04-05T15:56:21Z'},
#  {'Comment_Id_1': 'UgxVAIDAKXoyEgkWEeB4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': '<b>You can support my work here:</b><br><a href="https://www.patreon.com/SWFT">https://www.patreon.com/SWFT</a><br><a href="https://www.buymeacoffee.com/swft">https://www.buymeacoffee.com/swft</a>',
#   'Comment_Author': '@SWFT_edits',
#   'Comment_PublishedAt': '2024-03-22T17:54:51Z'},
#  {'Comment_Id_1': 'UgwCsR51jUOxNzj3kWZ4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Great storytelling man. Loved the flow as usual 🙌',
#   'Comment_Author': '@StarWarsCreations',
#   'Comment_PublishedAt': '2024-04-14T01:52:56Z'},
#  {'Comment_Id_1': 'UgwfJm2Us3sMFNldwah4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Good work!',
#   'Comment_Author': '@k0cherga',
#   'Comment_PublishedAt': '2024-04-12T17:50:12Z'},
#  {'Comment_Id_1': 'UgyuS6gi3DJq7xidS5B4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'These SW edits are superlative examples of mastery in storytelling!',
#   'Comment_Author': '@MyChillfactor',
#   'Comment_PublishedAt': '2024-04-12T01:55:12Z'},
#  {'Comment_Id_1': 'UgwpiA9d6BRcmRn3Pd14AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Seperatists need a video',
#   'Comment_Author': '@RamBread',
#   'Comment_PublishedAt': '2024-04-10T16:37:12Z'},
#  {'Comment_Id_1': 'UgxAeGg_3mHUhf1VVe14AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Incredible job! Amazing video!',
#   'Comment_Author': '@dariocp87',
#   'Comment_PublishedAt': '2024-04-06T22:05:42Z'},
#  {'Comment_Id_1': 'UgxVQAhlC0EsbIMINUh4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'This is why I love Star Wars<br>Thank you for this masterpiece of a summary!',
#   'Comment_Author': '@T04UBI',
#   'Comment_PublishedAt': '2024-04-06T10:17:41Z'},
#  {'Comment_Id_1': 'UgxP3HG4OmJqkdH5S9p4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Then the Empire started to slowly die as the people stood up and fought back.',
#   'Comment_Author': '@Afroman29',
#   'Comment_PublishedAt': '2024-04-06T02:34:01Z'},
#  {'Comment_Id_1': 'UgyCbtZKOTBkGCPQPwJ4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Palpatine controlled BOTH sides. There was no way he could loose.',
#   'Comment_Author': '@a.hoctavius5848',
#   'Comment_PublishedAt': '2024-04-05T22:44:08Z'},
#  {'Comment_Id_1': 'Ugxw-htXuKhiXGzZVWx4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Wait. Guys this video made me think of something. I always thought star wars fealt like a story about ww2 but this makes me realise the similarities between star wars and the USA.',
#   'Comment_Author': '@JustinJamesJeep',
#   'Comment_PublishedAt': '2024-04-05T01:11:27Z'},
#  {'Comment_Id_1': 'UgyOpXtnyt_2lWhcgw94AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Their “republic” was trash in the first place. Long live the Empire.',
#   'Comment_Author': '@reiniergarcia',
#   'Comment_PublishedAt': '2024-04-04T19:43:51Z'},
#  {'Comment_Id_1': 'UgwVp-JAnY_HT1r1n-R4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The moment at 4.00 ............. God the goosebumps!!!!!!!!!!!!!!!!!!!!!!!!!!! <br><br>Amazing clip in the video, but would have been amazing if it was the Sith code &quot;Peace is a lie&quot;',
#   'Comment_Author': '@shanemorgan5066',
#   'Comment_PublishedAt': '2024-04-04T15:19:36Z'},
#  {'Comment_Id_1': 'Ugw3muOZIcv97bLQES14AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The old republic germany have until an constition explaines wgivh is to light weight in justlce 2024a.c before  ew time accounting',
#   'Comment_Author': '@florianschramm1010',
#   'Comment_PublishedAt': '2024-04-02T21:23:30Z'},
#  {'Comment_Id_1': 'UgzdudjhtkOgQOtfx3x4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'feels like a warning for what&#39;s happening in the US right now',
#   'Comment_Author': '@jamesmartinek8832',
#   'Comment_PublishedAt': '2024-04-01T23:23:00Z'},
#  {'Comment_Id_1': 'UgzDhB-vE29X__lHyWR4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Amazing Video👍🏼',
#   'Comment_Author': '@mrhunter7087',
#   'Comment_PublishedAt': '2024-04-01T21:34:47Z'},
#  {'Comment_Id_1': 'UgzyUL_gIAQmGCGze394AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Thank You. I love the Fact that you put in the perspective of the Separatists who were being exploited through corruption by Mega corporations and others in the Inner Core, extracting their resources by any means. This was Exploited to the fullest by Palpatine to get the Republic and the Outer core to destroy each other and then swoop in with his clone army and get rid of the Jedi and control the galaxy. No one won, both sides were tricked and Lost in the End.',
#   'Comment_Author': '@uhfanzonly',
#   'Comment_PublishedAt': '2024-04-01T04:22:50Z'},
#  {'Comment_Id_1': 'UgwvSuciNSSqKrq2Qy54AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The character in real life would support global communism as long as it doesn&#39;t affect her income .',
#   'Comment_Author': '@rocky76dude7',
#   'Comment_PublishedAt': '2024-03-31T17:04:20Z'},
#  {'Comment_Id_1': 'UgyrNnZ5Jo5VZZyLmm54AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Nice edit man fr. Now we need a First Order&#39;s tribute',
#   'Comment_Author': '@iljoker6788',
#   'Comment_PublishedAt': '2024-03-31T12:31:37Z'},
#  {'Comment_Id_1': 'UgzF5_8OV7l3_YRfKtl4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'I&#39;m seeing a Republic, in the real world, has fallen exactly like the one depicted in Star Wars... Long live the bank',
#   'Comment_Author': '@sustainablerenewableintegr8311',
#   'Comment_PublishedAt': '2024-03-31T01:16:20Z'},
#  {'Comment_Id_1': 'UgzktaNH_DkyvZNoXgJ4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'you never disappoint.',
#   'Comment_Author': '@user-pl4iq3sb6v',
#   'Comment_PublishedAt': '2024-03-31T00:14:23Z'},
#  {'Comment_Id_1': 'Ugz2uHwVauXr3Yl0o4x4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'You&#39;ve bring voices from audiobook 《Dooku Jedi Lost》 right ?',
#   'Comment_Author': '@Toto-TK88',
#   'Comment_PublishedAt': '2024-03-30T12:30:55Z'},
#  {'Comment_Id_1': 'Ugzc74CLJxIm4_yraQV4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'This video truly is a masterpiece. Well done.',
#   'Comment_Author': '@blackstar2458',
#   'Comment_PublishedAt': '2024-03-30T08:57:25Z'},
#  {'Comment_Id_1': 'Ugx89VCAu3GIdXbxsEh4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Dude this edit is so good - it’s obvious how much work went into it just in the amount of content had to be gathered alone. Just this one part of the timeline could have so many of its own movies, series, etc. So many stories, especially in the ROTS-Andor years.',
#   'Comment_Author': '@AbsolutSpaceGirl',
#   'Comment_PublishedAt': '2024-03-30T05:35:02Z'},
#  {'Comment_Id_1': 'UgwIMc2vq5fUzPmM7yF4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'アニメ調じゃなくて実写のやつの作品名教えてほしいです‼️ローグワンしか見たことなくて、、、',
#   'Comment_Author': '@user-jv7jv6fz9l',
#   'Comment_PublishedAt': '2024-03-29T13:48:58Z'},
#  {'Comment_Id_1': 'UgyU25eTltdXfI8ROzN4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'A VERY good synopsis of that Era. Fantastic!',
#   'Comment_Author': '@timturner6240',
#   'Comment_PublishedAt': '2024-03-29T03:22:32Z'},
#  {'Comment_Id_1': 'Ugwe6dvbAauqVI-lBPJ4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'I would love to see people react to this…',
#   'Comment_Author': '@Kitty73024',
#   'Comment_PublishedAt': '2024-03-29T02:55:28Z'},
#  {'Comment_Id_1': 'UgwB1pQcUSNv8P0yoS94AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': '<b>nervously laughs at the parallels in reality</b>',
#   'Comment_Author': '@billyjenkins7951',
#   'Comment_PublishedAt': '2024-03-28T22:48:16Z'},
#  {'Comment_Id_1': 'UgyWNOQ-v9Iz-WlZ33F4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The only thing I would have made better with this edit, is that I shouldn&#39;t have waited so long to watch this masterpiece. Great work as ever.',
#   'Comment_Author': '@ShadowGh004',
#   'Comment_PublishedAt': '2024-03-28T20:01:22Z'},
#  {'Comment_Id_1': 'UgzgcXxLuT5EZEh3PQp4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'LONG LIVE THE EMPIRE !!!',
#   'Comment_Author': '@atakanerdur3',
#   'Comment_PublishedAt': '2024-03-28T19:16:51Z'},
#  {'Comment_Id_1': 'UgyCEilWc6bC_w7L0Pt4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The fact I can see parallels to this and government is crazy.',
#   'Comment_Author': '@jakeperez7663',
#   'Comment_PublishedAt': '2024-03-28T18:34:57Z'},
#  {'Comment_Id_1': 'UgyZh8xKiOn2xSZ9mxV4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'You are awesome, I love your work so much.  Every video you make is a masterpiece &lt;3',
#   'Comment_Author': '@ThePyroH3224',
#   'Comment_PublishedAt': '2024-03-28T16:29:02Z'},
#  {'Comment_Id_1': 'UgwrALSEMcDmIIUHw594AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Wow this is really good! Well done',
#   'Comment_Author': '@WolfTriggerMan',
#   'Comment_PublishedAt': '2024-03-28T13:00:30Z'},
#  {'Comment_Id_1': 'Ugx4XZCzPhZ-ZDDddPd4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'okay i know we had rebels but tbh I would want a show more like star wars the clone wars but Star Wars the Civil War, that depicts the civil war on a more grand scale just like the clone wars, and i know the rebel alliance are not as grand as the clone army but I would still love to see something more like that',
#   'Comment_Author': '@odsgaming105',
#   'Comment_PublishedAt': '2024-03-28T12:35:14Z'},
#  {'Comment_Id_1': 'UgxEFE8MH7JkkV7G3yt4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Masterpiece!',
#   'Comment_Author': '@MaddyWinkel',
#   'Comment_PublishedAt': '2024-03-28T09:50:34Z'},
#  {'Comment_Id_1': 'Ugz30dU3xxgxrl6ZbKp4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Brilliant - loved every second',
#   'Comment_Author': '@breadonitsown8950',
#   'Comment_PublishedAt': '2024-03-28T04:11:00Z'},
#  {'Comment_Id_1': 'UgwJBMyWqzVSp9fx37F4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Can you do the fall of the empire',
#   'Comment_Author': '@Bigdan678',
#   'Comment_PublishedAt': '2024-03-28T02:45:51Z'},
#  {'Comment_Id_1': 'UgySUkVdlFqec-LV1vl4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Ironic the lady who plays someone trying to uphold a democracy wants to destroy one in real life',
#   'Comment_Author': '@atlascormac6273',
#   'Comment_PublishedAt': '2024-03-28T01:53:00Z'},
#  {'Comment_Id_1': 'Ugwk8wbZMIToOSiIxxB4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'I saw this every time you upload but your editing choices are superb.  How do you go about deciding what soundbites to use and when?  It&#39;s so impressive.',
#   'Comment_Author': '@venomgames1077',
#   'Comment_PublishedAt': '2024-03-27T19:47:57Z'},
#  {'Comment_Id_1': 'UgwcXmNimxhZzYktyC94AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Yet another fantastic video SWFT. You are a legend.',
#   'Comment_Author': '@jonbaxter2254',
#   'Comment_PublishedAt': '2024-03-27T17:51:36Z'},
#  {'Comment_Id_1': 'UgwqoguRAicymOJatLZ4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Perfecto.',
#   'Comment_Author': '@Cybernaut551',
#   'Comment_PublishedAt': '2024-03-27T11:54:35Z'},
#  {'Comment_Id_1': 'Ugx1qkWQARevp6tF7XR4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@Babyboy7672',
#   'Comment_PublishedAt': '2024-03-27T11:39:58Z'},
#  {'Comment_Id_1': 'UgybwtqNrt9l--pUKcF4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'The ship alarms at <a href="https://www.youtube.com/watch?v=IxWsv9sCSF8&amp;t=80">1:20</a> ish are a good touch',
#   'Comment_Author': '@valoraboveall5793',
#   'Comment_PublishedAt': '2024-03-27T09:51:20Z'},
#  {'Comment_Id_1': 'UgzRkVf5sBHxAlulEp14AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'If you didn&#39;t already know that Star Wars is the best story ever told.... here&#39;s the video to prove it!',
#   'Comment_Author': '@Mr_Shweet',
#   'Comment_PublishedAt': '2024-03-27T09:00:57Z'},
#  {'Comment_Id_1': 'UgxY2OPJa2p1Wa97bOV4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Nicely well done compilation',
#   'Comment_Author': '@brentguy-wi5hw',
#   'Comment_PublishedAt': '2024-03-27T04:45:38Z'},
#  {'Comment_Id_1': 'UgwXwelRhKK2IEQPMfB4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'It&#39;s beautifully poetic, a very ideal video for even our own current global political situation the world finds itself in once again.',
#   'Comment_Author': '@DemoLoko55',
#   'Comment_PublishedAt': '2024-03-27T00:42:45Z'},
#  {'Comment_Id_1': 'UgxrhCR2otJsXhbaP3J4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'Where’s trump',
#   'Comment_Author': '@anthonyfowler2623',
#   'Comment_PublishedAt': '2024-03-26T23:41:16Z'},
#  {'Comment_Id_1': 'UgwvtDI6ZsmwtrGifyx4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'This is so cinematically beautiful man, great job!',
#   'Comment_Author': '@Zero-db8yk',
#   'Comment_PublishedAt': '2024-03-26T17:55:05Z'},
#  {'Comment_Id_1': 'UgyOmORq_XJoutOYJp14AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'flawless edit. Love it. good joob!',
#   'Comment_Author': '@Nitrogamer_',
#   'Comment_PublishedAt': '2024-03-26T17:21:20Z'},
#  {'Comment_Id_1': 'UgyDk-wXPEPiC-RD-9p4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'This is a fucking masterpiece, holy I am so impressed ! Thank you for the edit ❤',
#   'Comment_Author': '@sniperx4048',
#   'Comment_PublishedAt': '2024-03-26T16:52:52Z'},
#  {'Comment_Id_1': 'UgwckRWIQLPj_uw7mRx4AaABAg',
#   'video_Id': 'IxWsv9sCSF8',
#   'Comment_Text': 'what a masterpiece',
#   'Comment_Author': '@hellohelloington9442',
#   'Comment_PublishedAt': '2024-03-26T13:47:50Z'},
#  {'Comment_Id_1': 'UgwIwd6nWNzfJii8J1R4AaABAg',
#   'video_Id': 'Mk_oW98J8Cs',
#   'Comment_Text': 'Watch my previous video on the clones here! :) <br><br><a href="https://www.youtube.com/watch?v=lp5y-BeBq6g">https://youtu.be/lp5y-BeBq6g?si=YZyLVcVDl18q2Tsl</a>',
#   'Comment_Author': '@SWFT_edits',
#   'Comment_PublishedAt': '2024-03-15T19:46:28Z'},
#  {'Comment_Id_1': 'UgysyjgGWIkQb9qwI7F4AaABAg',
#   'video_Id': 'Mk_oW98J8Cs',
#   'Comment_Text': 'Will it come out on once bad batch is over?',
#   'Comment_Author': '@Imm0rta1us',
#   'Comment_PublishedAt': '2024-04-05T16:22:45Z'},
#  {'Comment_Id_1': 'UgwuxyzexXA3xk9KRwx4AaABAg',
#   'video_Id': 'Mk_oW98J8Cs',
#   'Comment_Text': 'Chills!!! Can&#39;t wait',
#   'Comment_Author': '@saracheung96',
#   'Comment_PublishedAt': '2024-03-26T23:14:18Z'},
#  {'Comment_Id_1': 'UgyZdhfGJv91ceaPd-B4AaABAg',
#   'video_Id': 'Mk_oW98J8Cs',
# ...
#   'Comment_Author': '@mortalkom5609',
#   'Comment_PublishedAt': '2023-12-19T17:19:19Z'},
#  {'Comment_Id_1': 'UgxCJl29gid3JApOhaB4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'it&#39;s so obvious it&#39;s sad<br><br>white face painted girl is &#39;on ♧top♤&#39;<br><br>and white storm troopers are entry level warriors',
#   'Comment_Author': '@pitr_de_vice_klamps',
#   'Comment_PublishedAt': '2023-12-12T10:33:09Z'},
#  {'Comment_Id_1': 'UgzW5FlpFXUOQ-rRvu94AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'The Force is incompatible with sapient nature',
#   'Comment_Author': '@comradekolbot2220',
#   'Comment_PublishedAt': '2023-12-11T00:29:52Z'},
#  {'Comment_Id_1': 'Ugyb1nSidB-1qQT8_F94AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'Baylan: &quot;As you get older, you look at history, and you realize that it&#39;s all inevitable. The fall of the Jedi. The rise of the Empire. It repeats again, and again, and again.&quot;<br><br>Shin: &quot;Then isn&#39;t it our turn, now? Won&#39;t our alliance with Thrawn finally bring us into power?&quot;<br><br>Baylan: &quot;That sort of power is fleeting. What I seek is the beginning, so I may finally bring this cycle to an end.&quot;',
#   'Comment_Author': '@Maltebyte2',
#   'Comment_PublishedAt': '2023-12-02T19:41:36Z'},
#  {'Comment_Id_1': 'UgzCIWK66dvJdfKqL_R4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'Jesus is the Way, the Truth and the Life',
#   'Comment_Author': '@mannam615',
#   'Comment_PublishedAt': '2023-11-29T12:57:25Z'},
#  {'Comment_Id_1': 'UgxYxvd3pGH-4mCIPqN4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'Dude wtf w the &quot;Preview Picture&quot;  i hate the channels/people that hang from other content &amp; spoil/make SPOILERS in the title, preview picture or the content itself, maybe its a good video but from me DISLIKE just bc dont care a shii¡¡¡¡ T to spoil',
#   'Comment_Author': '@bamrosas1687',
#   'Comment_PublishedAt': '2023-11-27T09:58:53Z'},
#  {'Comment_Id_1': 'UgwwcczBvXBBKBT-3cd4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'A canvas',
#   'Comment_Author': '@morrisirungu8712',
#   'Comment_PublishedAt': '2023-11-26T17:20:07Z'},
#  {'Comment_Id_1': 'UgzQ1PPo6QSmPWz84NV4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'MENGA MINT!!!',
#   'Comment_Author': '@SasukeGarage55',
#   'Comment_PublishedAt': '2023-11-17T08:23:28Z'},
#  {'Comment_Id_1': 'Ugy5Qfm0E33EQnge7L14AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'We need to see Revan, Maul, and Tyrannus edits!',
#   'Comment_Author': '@aku13745',
#   'Comment_PublishedAt': '2023-11-17T07:43:49Z'},
#  {'Comment_Id_1': 'UgzBBIZbBCwSxDE7o-B4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=y-JHoqA7B78&amp;t=301">5:01</a> &quot;fear is the path to the dark side&quot; / Truly the power of darkness is everywhere @<a href="https://www.youtube.com/watch?v=y-JHoqA7B78&amp;t=60">1:00</a>',
#   'Comment_Author': '@southernmostrebel',
#   'Comment_PublishedAt': '2023-11-15T07:10:36Z'},
#  {'Comment_Id_1': 'Ugw9PO-FkvMA7kb8tat4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'they want to be on their light anti-social media accounts war shipping rapu for light or mirror likes. that&#39;s it.',
#   'Comment_Author': '@pitr_de_vice_klamps',
#   'Comment_PublishedAt': '2023-11-11T23:50:33Z'},
#  {'Comment_Id_1': 'UgwHAs9aJWpxwD6Lait4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'most of the rapu war shippers don&#39;t even vote. they just want to war ship rapu',
#   'Comment_Author': '@pitr_de_vice_klamps',
#   'Comment_PublishedAt': '2023-11-11T23:49:04Z'},
#  {'Comment_Id_1': 'Ugy9moRTaB3V88pC-rN4AaABAg',
#   'video_Id': 'y-JHoqA7B78',
#   'Comment_Text': 'democrats have a whiteness problem too, but that&#39;s whiteness. paper white thin friendships',
#   'Comment_Author': '@pitr_de_vice_klamps',
#   'Comment_PublishedAt': '2023-11-11T23:43:43Z'},
#  {'Comment_Id_1': 'Ugxk0rey7eZRVVs7m4B4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '<b>I don&#39;t make money from my videos, so if you want to support me:</b><br><a href="https://www.patreon.com/SWFT">https://www.patreon.com/SWFT</a><br><a href="https://www.buymeacoffee.com/swft">https://www.buymeacoffee.com/swft</a>',
#   'Comment_Author': '@SWFT_edits',
#   'Comment_PublishedAt': '2023-05-23T18:12:17Z'},
#  {'Comment_Id_1': 'Ugx3rH-tkfTwlGWWfdZ4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Remember Jedha. Remember Alderaan. Remember Mandalore. Remember the Jedi. Remember every single cruelty and atrocity the Empire performed. They thought they could trample over everyone with no regard. They were wrong.',
#   'Comment_Author': '@samalvey8168',
#   'Comment_PublishedAt': '2024-04-13T15:59:24Z'},
#  {'Comment_Id_1': 'Ugw-2RolNauAufnivzR4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=oxtvvRmZFWU&amp;t=464">7:44</a> Yoda: Do or do not, there is no try.',
#   'Comment_Author': '@FreezeFun',
#   'Comment_PublishedAt': '2024-04-12T10:56:44Z'},
#  {'Comment_Id_1': 'Ugzfe8237FkyYx2Lp054AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'F**k The Empire',
#   'Comment_Author': '@wigglemd',
#   'Comment_PublishedAt': '2024-04-10T20:51:43Z'},
#  {'Comment_Id_1': 'UgxF_gulZWHAnQtTbtZ4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Can you split this video in 3? because the first part uses a lot of Andor and I want to convince my mom to watch it as well',
#   'Comment_Author': '@teagan5494',
#   'Comment_PublishedAt': '2024-04-09T00:34:59Z'},
#  {'Comment_Id_1': 'UgyjYhYwre1_r7ysiYl4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Wow this was amazingly put together',
#   'Comment_Author': '@jCondrea',
#   'Comment_PublishedAt': '2024-04-08T09:27:45Z'},
#  {'Comment_Id_1': 'Ugy7MSQjVYtnlyandQ54AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'This music is from the (unjustly...) cancelled HBO series, *Westworld*.',
#   'Comment_Author': '@samuelfitzpatrick2784',
#   'Comment_PublishedAt': '2024-04-06T15:56:02Z'},
#  {'Comment_Id_1': 'Ugxf2KHaz-B-cuowbJR4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'This is amazing!!!',
#   'Comment_Author': '@rjwallace7477',
#   'Comment_PublishedAt': '2024-04-06T05:26:09Z'},
#  {'Comment_Id_1': 'UgzD1T7gqrFg9Yf3T-t4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Long live the empire!!',
#   'Comment_Author': '@jonathanphilip7468',
#   'Comment_PublishedAt': '2024-04-05T17:22:30Z'},
#  {'Comment_Id_1': 'UgzWarQW9OkZSxxAj354AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Can we just take a moment and recognize how much the themes of tyranny, power, oppression, freedom, human desperation, and the will to fight resonate in all of us?<br>This was very well done, and very powerful.',
#   'Comment_Author': '@tomchidwick',
#   'Comment_PublishedAt': '2024-04-05T03:28:32Z'},
#  {'Comment_Id_1': 'UgyjvsubB78qs3DcRy54AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Andor was perfect and they really just keep putting out shit',
#   'Comment_Author': '@generalinbox3740',
#   'Comment_PublishedAt': '2024-04-04T14:31:56Z'},
#  {'Comment_Id_1': 'Ugyv3b2kStqQF6a79hN4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'very nice',
#   'Comment_Author': '@kolinbrannon998',
#   'Comment_PublishedAt': '2024-04-03T15:44:08Z'},
#  {'Comment_Id_1': 'UgzrG0-m46cwM-8usK14AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=oxtvvRmZFWU&amp;t=253">4:13</a> LONG LIVE THE EMPIRE!',
#   'Comment_Author': '@FN-9184',
#   'Comment_PublishedAt': '2024-03-30T23:54:12Z'},
#  {'Comment_Id_1': 'UgzhGJKJqFiY84YSNhJ4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'СЛАВА ПЕРВОЙ ГАЛАКТИЧЕСКОЙ ИМПЕРИИ!!!',
#   'Comment_Author': '@user-wi8ni4dj7k',
#   'Comment_PublishedAt': '2024-03-30T18:46:38Z'},
#  {'Comment_Id_1': 'UgxfKp6QmaDUwIyK3VB4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'LONG LIVE THE EMPIRE !!!',
#   'Comment_Author': '@atakanerdur3',
#   'Comment_PublishedAt': '2024-03-28T19:23:23Z'},
#  {'Comment_Id_1': 'UgxqzorI8RbxVmQ6Thx4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Desert thats not even good enough to be wasted in front of those…tailored bodies who are here?',
#   'Comment_Author': '@bunk95',
#   'Comment_PublishedAt': '2024-03-27T22:58:05Z'},
#  {'Comment_Id_1': 'Ugyzi0GvvFVFO9rtaxt4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Andor is the best star wars project',
#   'Comment_Author': '@d_n_j6298',
#   'Comment_PublishedAt': '2024-03-26T18:45:07Z'},
#  {'Comment_Id_1': 'UgxnPml2r3m2zv8nKmF4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'I like how throughout this ENTIRE video, Palpatine is seldomly shown or mentioned, and is instead the invisible driving force behind the Empire. <br>The oppression, cruelty, tyranny, and disorder circles back to him, and he&#39;s not hiding, he&#39;s just merely the darkness within.',
#   'Comment_Author': '@anlexaify',
#   'Comment_PublishedAt': '2024-03-24T05:28:04Z'},
#  {'Comment_Id_1': 'UgwwwbsqG-9-BVkoa6N4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Republic must fall. LONG LIVE THE EMPIRE!',
#   'Comment_Author': '@xSolidLewisx',
#   'Comment_PublishedAt': '2024-03-22T13:45:27Z'},
#  {'Comment_Id_1': 'UgxojrXIMsPXdFuES-V4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Why is order considered to be bad ? The alternative of order ir chaos. Better order than chaos.',
#   'Comment_Author': '@Jovan_Jarkarane',
#   'Comment_PublishedAt': '2024-03-20T21:19:10Z'},
#  {'Comment_Id_1': 'Ugygtaka68SvJ8RBZcx4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '와우! 엄청난 정치 선동 필름이네...',
#   'Comment_Author': '@heyowow6344',
#   'Comment_PublishedAt': '2024-03-20T03:44:29Z'},
#  {'Comment_Id_1': 'UgyMxhAVmgQw5znVt2J4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'DEMOCRACY THRIVES IN DARKNESS',
#   'Comment_Author': '@jonytequileiro',
#   'Comment_PublishedAt': '2024-03-19T15:48:23Z'},
#  {'Comment_Id_1': 'UgyZqKiV74Lrjp8YeId4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'How many people realize that Star Wars is just a projection of what is happening in our real world ? Among many other creation of anti-imperialism works of art: Dune, Avatar, Foundation.',
#   'Comment_Author': '@gushterell7989',
#   'Comment_PublishedAt': '2024-03-17T20:43:55Z'},
#  {'Comment_Id_1': 'UgyKdaN5m1SvjdeMziV4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'imagine if at the end instead of it finishing with &quot;try&quot; it finishes instead with &quot;try&quot; and then yoda saying &quot;do or do not, there is no try&quot;',
#   'Comment_Author': '@anthonyabboud4638',
#   'Comment_PublishedAt': '2024-03-16T02:20:28Z'},
#  {'Comment_Id_1': 'UgzzrwFW46MT2DWuT0p4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'This video makes me want to fight for the resistance',
#   'Comment_Author': '@barryfortnite3849',
#   'Comment_PublishedAt': '2024-03-14T21:41:14Z'},
#  {'Comment_Id_1': 'UgwnNIDS8TYmi5dcHnN4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Very cool.',
#   'Comment_Author': '@blasternavs',
#   'Comment_PublishedAt': '2024-03-13T18:25:22Z'},
#  {'Comment_Id_1': 'UgzD76fmyhQ7ZnvslyN4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'May Disney hire you immediately as their Lead editor for all projects going forward. Your every edit is far far better than anything Disney Star Wars has been able to produce. Come on Disney... start hiring REAL talent and save Star Wars!!!!',
#   'Comment_Author': '@iromek',
#   'Comment_PublishedAt': '2024-03-10T13:47:18Z'},
#  {'Comment_Id_1': 'Ugx9ALECuWzna-toY4l4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'There is no perfect system. But in comparison to the one that came than the one that came before, the Empire is better. <br>&quot;The Empire improves every system it touches&quot; - The Client.<br>While the Republic mined all of the outer systems and enrich the core systems, the Empire improves them. The Republic is made upon thousands of senators only worrying about their own system rather the entire Republic as a whole. That&#39;s corruption. They serve their own system. The Empire removed the senate, and every system is governed by regional governors working for the Empire, not a local system. A sense of stability, security, and prosperity exist, as the Emperor has said.<br>And to the one that came after the Empire, the New Republic, was as unstable as the former Republic. No sense of government exist in the outer rim, such planet is Nevarro, once governed by rules of the Empire, has fallen to a planet of bandits, bounty hunters, and criminals. As the Client said; &quot;I see nothing but chaos.&quot;',
#   'Comment_Author': '@novaxvarsity',
#   'Comment_PublishedAt': '2024-03-10T12:06:55Z'},
#  {'Comment_Id_1': 'UgxFCKJYNqd2p2U0lf54AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '621 канстантинкарольмадинавна ккм фсьэтолстыйэгавнапузикистарыйэтусклыйэмарщынистыйэкарликибалгарыскароткиминагамикалисомчырнакожыйэгарбатыйэлысыйэсчорнымибычымийайцамивмьэстагласбьэзубыйэбьэзгландныйэнищыйэбамжываньайущыйэсракай калаутдарьъ льэнаэйръ карлушэйръ грамишуъ гнизфаъ крышгъ солбарныйудагъ стикшуъ скизимъ',
#   'Comment_Author': '@dilured',
#   'Comment_PublishedAt': '2024-03-09T23:09:48Z'},
#  {'Comment_Id_1': 'Ugz_D3RHcjJ-YkcLdnx4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'I was expecting a fucking video essay, not this shit.',
#   'Comment_Author': '@michaelchen2718',
#   'Comment_PublishedAt': '2024-03-09T23:04:12Z'},
#  {'Comment_Id_1': 'Ugz7a_xWhQQ48SJhYF54AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Long live the Empire',
#   'Comment_Author': '@caps187',
#   'Comment_PublishedAt': '2024-03-07T21:56:07Z'},
#  {'Comment_Id_1': 'UgzCGvy4_U8A1oU2H_N4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'terrorist propaganda',
#   'Comment_Author': '@stijnberendsen2733',
#   'Comment_PublishedAt': '2024-03-07T17:58:49Z'},
#  {'Comment_Id_1': 'UgwRWADqdroM__5siH54AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'Your edits are really high quality. Great video.',
#   'Comment_Author': '@BeforetheStorm.',
#   'Comment_PublishedAt': '2024-03-06T21:42:11Z'},
#  {'Comment_Id_1': 'Ugxmp5C0sv3Zmy2mxXd4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'you&#39;re confusing peace with terms.  Ancient classic.',
#   'Comment_Author': '@chriswhited',
#   'Comment_PublishedAt': '2024-03-05T19:34:48Z'},
#  {'Comment_Id_1': 'Ugw33Xo0h_66nFOe3Al4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'its weird to think that even after the emperor died, the empire still had so much military and resources left but it all collapsed, but from that collapse rose the first order',
#   'Comment_Author': '@locaytion',
#   'Comment_PublishedAt': '2024-03-05T12:20:08Z'},
#  {'Comment_Id_1': 'UgzYUh_3041HicaOZxl4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=oxtvvRmZFWU&amp;t=315">5:15</a> is my favorite quote in all of star Wars.',
#   'Comment_Author': '@JNB0723',
#   'Comment_PublishedAt': '2024-03-05T01:31:01Z'},
#  {'Comment_Id_1': 'Ugz40C1zM4cttYnjK6B4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'it&#39;s the same with all corporation&#39;s transitions.  Maybe there is a positive byproduct.  But once the final game comes, you&#39;re fucked. In the end your comfort is their loss and your pain is their gain, almost by LITERAL DEFINITION.',
#   'Comment_Author': '@chriswhited',
#   'Comment_PublishedAt': '2024-03-05T01:13:17Z'},
#  {'Comment_Id_1': 'UgyPAqsGwW-cZxyXXxt4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'the imperial need for control is so desperate because its so unatural',
#   'Comment_Author': '@user-tt7dy1hf3x',
#   'Comment_PublishedAt': '2024-03-04T23:12:23Z'},
#  {'Comment_Id_1': 'UgyJeeCBT6z1j9ebi_h4AaABAg',
#   'video_Id': 'oxtvvRmZFWU',
#   'Comment_Text': 'The fact that a majority of the lines are from Andor shows how spectacularly the show is written!',
#   'Comment_Author': '@darthgamer9468',
#   'Comment_PublishedAt': '2024-03-04T14:24:19Z'},
#  ...]

# %%
def get_playlistID_info(Channel_ID):
    Initial_p_Token = None
    playlist_ids = []

    while True:
        request = youtube.playlists().list(
                part="snippet,contentDetails",
                channelId= Channel_ID,
                maxResults= 50,
                pageToken = Initial_p_Token
            )
        response = request.execute()

        for p_ID in response['items']:
            d4 = dict(
            channel_Name = p_ID['snippet']['channelTitle'],
            channel_id = p_ID['snippet']['channelId'],
            playlist_name = p_ID['snippet']['title'],
            playlist_id = p_ID['id'])

            playlist_ids.append(d4)
        
        Initial_p_Token = response.get('nextPageToken')
        if Initial_p_Token is None:
            break

    return playlist_ids

# %%
p = get_playlistID_info("UCFdNVWyDVrVUpTb-2SlDFqg")

# %%
p
# Out:
# [{'channel_Name': 'SWFT',
#   'channel_id': 'UCFdNVWyDVrVUpTb-2SlDFqg',
#   'playlist_name': 'Dune Videos',
#   'playlist_id': 'PLZwnTgeZyHS3K00q_fV9QJm5dUnW05HF-'},
#  {'channel_Name': 'SWFT',
#   'channel_id': 'UCFdNVWyDVrVUpTb-2SlDFqg',
#   'playlist_name': 'Star Wars Videos',
#   'playlist_id': 'PLZwnTgeZyHS18wyumAZTZThh3OPJpLj5j'},
#  {'channel_Name': 'SWFT',
#   'channel_id': 'UCFdNVWyDVrVUpTb-2SlDFqg',
#   'playlist_name': 'Favorite Edits',
#   'playlist_id': 'PLZwnTgeZyHS2Bh535439iyq0b12j51ed7'},
#  {'channel_Name': 'SWFT',
#   'channel_id': 'UCFdNVWyDVrVUpTb-2SlDFqg',
#   'playlist_name': 'Unlisted Videos',
#   'playlist_id': 'PLZwnTgeZyHS05kDKVoktvvClf2Cl8jNfz'}]

# %%
#Transfering data into mongodb
client = pymongo.MongoClient("mongodb+srv://karthikkriz:kk07ch30@cluster0.setsqbw.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
database = client["capproj"]
collections = database['YoutubeChannelDetails']

# %%
def Channel_Full_Details(channel_ID):
    channel_details = get_ch_info(channel_ID)
    playlist_details = get_playlistID_info(channel_ID)
    All_Video_IDs = get_video_ids(channel_ID)
    video_details = get_video_info(channel_ID)
    comments_details = get_comments_info(channel_ID)

    collections.insert_one({"channel": channel_details, "playlist": playlist_details,
                            "video": video_details, "comments": comments_details})
    
    return "Transfering is completed"

# %%
inserting_Channel = Channel_Full_Details("UCFdNVWyDVrVUpTb-2SlDFqg")

# %%
inserting_Channel
# Out:
# 'Transfering is completed'

# %%
#channel creation in sql and mongodb
def All_ch_table():
    mydb = psycopg2.connect(
        host = "localhost",
        user = "postgres",
        password = "kk07ch30",
        database = "capproj",
        port = "5432"
    )

    mycursor = mydb.cursor()

    drop_query = '''drop table if exists channels'''
    mycursor.execute(drop_query)
    mydb.commit()

    try:
        create_query = '''create table if not exists channels(Channel_name varchar(30),
                                                            channel_id varchar(30) primary key,
                                                            Subscription_Count bigint,
                                                            Channel_Views bigint,
                                                            Channel_Description text
                                                            )'''
        
        mycursor.execute(create_query)
        mydb.commit()
    except:
        print("Table is already created")


    c_list = []
    database = client["capproj"]
    collections = database["YoutubeChannelDetails"]

    for c in collections.find({},{"_id": 0, "channel": 1}):
        c_list.append(c['channel'])

    df = pd.DataFrame(c_list)    


    for index,row in df.iterrows():
            insert_query = '''insert into channels(Channel_name,
                                                channel_id,
                                                Subscription_Count,
                                                Channel_Views,
                                                Channel_Description)
                                                
                                                values(%s,%s,%s,%s,%s)'''
            
            val= (row['Channel_name'],
                row['channel_id'],
                row['Subscription_Count'],
                row['Channel_Views'],
                row['Channel_Description'])
            
            try:
                mycursor.execute(insert_query,val)
                mydb.commit()

            except:
                print("channel details are already inserted")

# %%
#playlist creation in sql and mongodb
def All_Playist_table():
    mydb = psycopg2.connect(
        host = "localhost",
        user = "postgres",
        password = "kk07ch30",
        database = "capproj",
        port = "5432"
    )

    mycursor = mydb.cursor()

    drop_query = '''drop table if exists playlists'''
    mycursor.execute(drop_query)
    mydb.commit()


    create_query = '''create table if not exists playlists(
    channel_Name varchar(150),
    channel_id varchar(150),
    playlist_name varchar(200),
    playlist_id varchar(150) primary key
    )'''


    mycursor.execute(create_query)
    mydb.commit()



    play_list = []
    database = client["capproj"]
    collections = database["YoutubeChannelDetails"]

    for p in collections.find({},{"_id": 0, "playlist": 1}):
        for i in range(len(p['playlist'])):
            play_list.append(p['playlist'][i])
    df1 = pd.DataFrame(play_list)



    for index,row in df1.iterrows():
            insert_query = '''insert into playlists(
            channel_Name,
            channel_id,
            playlist_name,
            playlist_id 
            )
            
            values(%s,%s,%s,%s) '''

            
            val = (row['channel_Name'],
                row['channel_id'],
                row['playlist_name'],
                row['playlist_id'])
            
            mycursor.execute(insert_query,val)
            mydb.commit()

# %%
#video creation in sql and mongodb
def All_video_table():
    mydb = psycopg2.connect(
            host = "localhost",
            user = "postgres",
            password = "kk07ch30",
            database = "capproj",
            port = "5432"
        )

    mycursor = mydb.cursor()

    drop_query = '''drop table if exists video'''
    mycursor.execute(drop_query)
    mydb.commit()


    create_query = '''create table if not exists video(Video_Id varchar(40) primary key,
                                                        Channel_Name varchar(100),
                                                        Channel_ID varchar(100),
                                                        Video_Name varchar(700),
                                                        Video_Description text,
                                                        Tags text,
                                                        PublishedAt timestamp,
                                                        View_Count bigint,
                                                        Like_Count bigint,
                                                        Dislike_Count bigint,
                                                        Favorite_Count int,
                                                        Comment_Count int,
                                                        Duration interval,
                                                        Thumbnail varchar(200),
                                                        caption_status varchar(20)
                                                        )'''
                            

    mycursor.execute(create_query)
    mydb.commit()


    vi_list = []
    database = client["capproj"]
    collections = database["YoutubeChannelDetails"]

    for v_data in collections.find({},{"_id": 0, "video": 1}):
        for i in range(len(v_data['video'])):
            vi_list.append(v_data['video'][i])
    df2 = pd.DataFrame(vi_list)



    for index, row in df2.iterrows():
            insert_query = '''insert into video(
                Video_Id,
                Channel_Name,
                Channel_ID,
                Video_Name,
                Video_Description,
                Tags,
                PublishedAt,
                View_Count,
                Like_Count,
                Dislike_Count,
                Favorite_Count,
                Comment_Count,
                Duration,
                Thumbnail,
                caption_status
            )

            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s) '''

            val = (
                row['Video_Id'],
                row['Channel_Name'],
                row['Channel_ID'],
                row['Video_Name'],
                row['Video_Description'],
                row['Tags'],
                row['PublishedAt'],
                row['View_Count'],
                row['Like_Count'],
                row['Dislike_Count'],
                row['Favorite_Count'],
                row['Comment_Count'],
                row['Duration'],
                row['Thumbnail'],
                row['caption_status']
            )

            mycursor.execute(insert_query, val)
            mydb.commit()

# %%
vi_list = []
database = client["capproj"]
collections = database["YoutubeChannelDetails"]

for v_data in collections.find({},{"_id": 0, "video": 1}):
    for i in range(len(v_data['video'])):
        vi_list.append(v_data['video'][i])
df2 = pd.DataFrame(vi_list)

# %%
df2

# %%
#comments creation in sql and mongodb
def All_com_table():
    mydb = psycopg2.connect(
            host="localhost",
            user="postgres",
            password="kk07ch30",
            database="capproj",
            port="5432"
        )

    mycursor = mydb.cursor()

    drop_query = '''DROP TABLE IF EXISTS comments'''
    mycursor.execute(drop_query)
    mydb.commit()

    create_query = '''CREATE TABLE IF NOT EXISTS comments(
            Comment_Id_1 VARCHAR(200),
            video_Id varchar(200),
            Comment_Text text,
            Comment_Author VARCHAR(100),
            Comment_PublishedAt TIMESTAMP
        )'''
    mycursor.execute(create_query)
    mydb.commit()



    com_list = []
    database = client["capproj"]
    collections = database["YoutubeChannelDetails"]

    for com_data in collections.find({}, {"_id": 0, "comments": 1}):
            for i in range(len(com_data['comments'])):
                com_list.append(com_data['comments'][i])
    df3 = pd.DataFrame(com_list)



    for index, row in df3.iterrows():
            insert_query = '''insert into comments(
                Comment_Id_1,
                video_Id,
                Comment_Text,
                Comment_Author,
                Comment_PublishedAt
            )

            values(%s,%s,%s,%s,%s) '''

            val = (
                row['Comment_Id_1'],
                row['video_Id'],
                row['Comment_Text'],
                row['Comment_Author'],
                row['Comment_PublishedAt']
            )

            mycursor.execute(insert_query, val)
            mydb.commit()

# %%
def All_tables():
    All_ch_table()
    All_Playist_table()
    All_video_table()
    All_com_table()

    return "Tables created successfully"

# %%
t = All_tables()

# %%
t
# Out:
# 'Tables created successfully'

# %%
def view_ch_table():
    c_list = []
    db = client["capproj"]
    collections = db["YoutubeChannelDetails"]

    for c in collections.find({}, {"_id": 0, "channel": 1}):
        c_list.append(c['channel'])

    df1 = st.dataframe(c_list)

    return df1

# %%
def view_ph_table():
    play_list = []
    db = client["capproj"]
    collections = db["YoutubeChannelDetails"]

    for p in collections.find({}, {"_id": 0, "playlist": 1}):
        for i in range(len(p['playlist'])):
            play_list.append(p['playlist'][i])
    df2 = st.dataframe(play_list)

    return df2

# %%
def view_vi_table():
    vi_list = []
    db = client["capproj"]
    collections = db["YoutubeChannelDetails"]

    for v_data in collections.find({}, {"_id": 0, "video": 1}):
        for i in range(len(v_data['video'])):
            vi_list.append(v_data['video'][i])
    df3 = st.dataframe(vi_list)

    return df3

# %%
def view_com_table():
    com_list = []
    db = client["capproj"]
    collections = db["YoutubeChannelDetails"]

    for com_data in collections.find({}, {"_id": 0, "comments": 1}):

        for i in range(len(com_data['comments'])):
            com_list.append(com_data['comments'][i])
    df4 = st.dataframe(com_list)

    return df4

# %%
#streamlit

with st.sidebar:
    st.title(":orange[YOUTUBE SCRAPPING]")
    st.header("Skills Take Away")
    st.caption("python Scripts")
    st.caption("Data Collections")
    st.caption("Data Management Using MongoDB and SQL")


channel_number_input = st.text_input("Enter the Channel ID")

if st.button("Collect and store data"):
    channel_numbers=[]
    database = client["capproj"]
    collections = database["YoutubeChannelDetails"]

    for ci in collections.find({},{"_id": 0, "channel": 1}):
        channel_numbers.append(ci['channel']['channel_id'])

    if channel_number_input in channel_numbers:
        st.success("GIVEN ID ALREADY EXISTS SO TRY ANOTHER ONE")

    else:
        insert= YoutubeChannelDetails(channel_number_input)
        st.success(insert)
            

if st.button("Migrate to SQL"):
    T = All_tables()
    st.success(T)

View_table = st.radio("SELECT ANY OF THE FOLLOWING TO VIEW",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if View_table=="CHANNELS":
    view_ch_table()

elif View_table=="PLAYLISTS":
    view_ph_table()   

elif View_table=="VIDEOS":
    view_vi_table()

elif View_table=="COMMENTS":
    view_com_table()

# %%
mydb = psycopg2.connect(
    host = "localhost",
    user = "postgres",
    password = "kk07ch30",
    database = "capproj",
    port = "5432"
)

mycursor = mydb.cursor()


questions = [
    "What are the names of all the videos and their corresponding channels?",
    "Which channels have the most number of channel views?",
    "What are the top 10 most viewed videos and their respective channels?",
    "How many comments were made on each videos?",
    "Which video have the lowest number of likes, and what is the corresponding channel name?"]


queries = [
    '''select video_name, Channel_name from video''',
    '''select channel_name, Channel_views from channels order by channel_views desc limit 1''',
    '''select channel_name, view_count from video order by view_count desc limit 10''',
    '''select comment_id_1, video_id from comments group by video_id''',
    '''select channel_name, video_name, like_count from video order by like_count asc limit 1''']


st.title("Video and Channel Information")
selected_question = st.selectbox("Select Your Question", questions)

if selected_question:
    # Get the index of the selected question
    index = questions.index(selected_question)
    
    # Get the corresponding query
    query = queries[index]


    mycursor.execute(query)
    mydb.commit()


    results = mycursor.fetchall()


    if results:
        df = pd.DataFrame(results, columns=[col.name for col in mycursor.description])
        st.write(df)

    else:
         st.write("No results found.")


mycursor.close()
mydb.close()

# %%
#sql questions

mydb = psycopg2.connect(
    host = "localhost",
    user = "postgres",
    password = "kk07ch30",
    database = "capproj",
    port = "5432"
)

mycursor = mydb.cursor()

questions = st.selectbox("Select Your Question",
                   ("1. What are the names of all the videos and their corresponding channels?",
                    "2. Which channels have the most number of videos, and how many videos do they have?",
                    "3. What are the top 10 most viewed videos and their respective channels?",
                    "4. How many comments were made on each video, and what are their corresponding video names?",
                    "5. Which videos have the highest number of likes, and what are their corresponding channel names?",
                    "6. What is the total number of likes and dislikes for each video, and what are their corresponding video names?",
                    "7. What is the total number of views for each channel, and what are their corresponding channel names?",
                    "8. What are the names of all the channels that have published videos in the year 2022?",
                    "9. What is the average duration of all videos in each channel, and what are their corresponding channel names?",
                    "10. Which videos have the highest number of comments, and what are their corresponding channel names?"))

# %%
mydb = psycopg2.connect(
    host = "localhost",
    user = "postgres",
    password = "kk07ch30",
    database = "capproj",
    port = "5432"
)

mycursor = mydb.cursor()


# Que=="1. What are the names of all the videos and their corresponding channels?"
Query1 =  '''select video_id, COUNT(comment_id_1) from comments group by video_id'''
mycursor.execute(Query1)
mydb.commit()
t1 = mycursor.fetchall()
df = pd.DataFrame(t1,columns=["video id","comments number"])
df
